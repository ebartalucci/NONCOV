# %%
import matplotlib.pyplot as plt

def generate_1d_nmr_plot(nucleus, data, x_axis_length=10):
    """
    Generate a 1D NMR plot based on input data and nucleus type.

    Parameters:
    - nucleus (str): Nucleus type (e.g., "1H" or "13C").
    - data (list): List of NMR data points.
    - x_axis_length (float): Length of the x-axis.

    Returns:
    - None (displays the plot).
    """
    plt.figure(figsize=(x_axis_length, 4))  # Adjust figure size as needed
    plt.plot(data, label=f"{nucleus} NMR Data")
    plt.title(f"{nucleus} NMR Spectrum")
    plt.xlabel("Chemical Shift (ppm)")
    plt.ylabel("Intensity")
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage:
nmr_data_1H = [0.2, 0.8, 1.5, 2.3, 3.5, 4.2, 4.8]
generate_1d_nmr_plot("1H", nmr_data_1H, x_axis_length=12)

nmr_data_13C = [10.2, 20.5, 30.1, 40.0, 50.8]
generate_1d_nmr_plot("13C", nmr_data_13C, x_axis_length=8)

# %%
import matplotlib.pyplot as plt

def generate_1d_nmr_plot(nucleus, data):
    """
    Generate a 1D NMR plot based on input data and nucleus type.

    Parameters:
    - nucleus (str): Nucleus type (e.g., "1H" or "13C").
    - data (list): List of NMR data points.

    Returns:
    - None (displays the plot).
    """
    nucleus_info = {
        "1H": {"x_axis_length": 12, "title": "1H NMR Spectrum"},
        "13C": {"x_axis_length": 8, "title": "13C NMR Spectrum"},
        # Add more nuclei as needed
    }

    if nucleus in nucleus_info:
        info = nucleus_info[nucleus]
        x_axis_length = info["x_axis_length"]
        plot_title = info["title"]

        plt.figure(figsize=(x_axis_length, 4))  # Adjust figure size as needed
        plt.plot(data, label=f"{nucleus} NMR Data")
        plt.title(plot_title)
        plt.xlabel("Chemical Shift (ppm)")
        plt.ylabel("Intensity")
        plt.legend()
        plt.grid(True)
        plt.show()
    else:
        print(f"Unsupported nucleus type: {nucleus}")

# Example usage:
nmr_data_1H = [0.2, 0.8, 1.5, 2.3, 3.5, 4.2, 4.8]
generate_1d_nmr_plot("1H", nmr_data_1H)

nmr_data_13C = [10.2, 20.5, 30.1, 40.0, 50.8]
generate_1d_nmr_plot("13C", nmr_data_13C)

# Add more examples for other nuclei if needed

# %%
import matplotlib.pyplot as plt

def generate_custom_plot(data, keywords):
    """
    Generate a custom plot based on the provided data and keywords.

    Parameters:
    - data (list): The data to be plotted.
    - keywords (list): List of keywords found in the input file.

    Returns:
    - None (displays the plot).
    """
    if "$1D" in keywords:
        # If "$1D" keyword is found, handle 1D plot options
        plot_type_1D = keywords[keywords.index("$1D") + 1]  # Get the next keyword after "$1D"
        
        if plot_type_1D == "option_1":
            # Define option_1-specific parameters for 1D plot
            x_axis_length = 10
            title = "1D Plot Option 1"
            # Customize other plot parameters for option_1

            # Create and display the 1D plot
            plt.figure(figsize=(x_axis_length, 4))
            plt.plot(data)
            plt.title(title)
            # Set other plot properties for option_1

        elif plot_type_1D == "option_2":
            # Define option_2-specific parameters for 1D plot
            x_axis_length = 8
            title = "1D Plot Option 2"
            # Customize other plot parameters for option_2

            # Create and display the 1D plot
            plt.figure(figsize=(x_axis_length, 4))
            plt.plot(data)
            plt.title(title)
            # Set other plot properties for option_2

        # Add more elif blocks for other 1D plot options

        else:
            print(f"Unsupported 1D plot option: {plot_type_1D}")

    elif "$2D" in keywords:
        # If "$2D" keyword is found, handle 2D plot options
        plot_type_2D = keywords[keywords.index("$2D") + 1]  # Get the next keyword after "$2D"
        
        if plot_type_2D == "option_A":
            # Define option_A-specific parameters for 2D plot
            x_axis_length = 12
            title = "2D Plot Option A"
            # Customize other plot parameters for option_A

            # Create and display the 2D plot
            plt.figure(figsize=(x_axis_length, 6))
            plt.imshow(data, cmap='viridis', aspect='auto', origin='lower')
            plt.title(title)
            # Set other plot properties for option_A

        elif plot_type_2D == "option_B":
            # Define option_B-specific parameters for 2D plot
            x_axis_length = 10
            title = "2D Plot Option B"
            # Customize other plot parameters for option_B

            # Create and display the 2D plot
            plt.figure(figsize=(x_axis_length, 6))
            plt.imshow(data, cmap='coolwarm', aspect='auto', origin='lower')
            plt.title(title)
            # Set other plot properties for option_B

        # Add more elif blocks for other 2D plot options

        else:
            print(f"Unsupported 2D plot option: {plot_type_2D}")

    else:
        print("No valid plot keyword found in the input.")

    plt.show()

# Example usage:
plot_data = [[1, 2, 3], [4, 5, 6], [7, 8, 9]]  # Example 2D data
input_keywords = ["$2D", "option_B"]  # Example input keywords

generate_custom_plot(plot_data, input_keywords)
