# %% [markdown]
# # NONCOVToolbox: Step 2
# ## Generate the datasets from the ORCA output files with @OrcaAnalysis

# %% [markdown]
# Use the OrcaAnalysis module of the NONCOVToolbox to postprocess the ORCA output files from DFT calculations and save data to csv pandas dataframe.

# %% [markdown]
# ### Load necessary modules from the NONCOVToolbox src

# %%
# Get the NONCOVToolbox library and print header
# %load_ext autoreload
# %autoreload 2

import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import glob
import numpy as np
from sklearn.cluster import KMeans
import pathlib as Path
import importlib

path_noncov = os.path.abspath(os.path.join('..', '..', 'src'))

if path_noncov not in sys.path:
    sys.path.append(path_noncov)

from noncov import NONCOVToolbox, NONCOVHeader

noncov = NONCOVToolbox()

#NONCOVHeader.print_header()

# OrcaAnalysis module for postprocessing of DFT calculations
from noncov import OrcaAnalysis

# Functions to store data in dataframes
from noncov import MachineLearning

# Show performance and features of various NMR functions in module
from noncov import NMRFunctions

# Disable printing
def blockPrint():
    sys.stdout = open(os.devnull, 'w')

# Restore printing
def enablePrint():
    sys.stdout = sys.__stdout__
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Get work directory and scratch folder for the output data
current_dir = os.getcwd()
print(f'Current work directory is: {current_dir}')

scratch_dir = os.path.abspath(os.path.join('..', '..', 'scratch'))
print(f'Current scratch directory is: {scratch_dir}')
scratch_dir = OrcaAnalysis().convert_path(scratch_dir)
# Out:
# Current work directory is: /Users/ettorebartalucci/Desktop/NONCOV/examples/KLaL_Cation_Pi_SGP
# Current scratch directory is: /Users/ettorebartalucci/Desktop/NONCOV/scratch
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch

# %% [markdown]
# ### Preallocate two empty dataframes for ML applications

# %%
# Check whether a database exists in your directory and create it if it doesnt
datasets_dir = os.path.join(scratch_dir, 'GenerateMLDataset/data/KLaL2/')
print(f'Dataset directory is: {datasets_dir}')
datasets_dir = OrcaAnalysis().convert_path(datasets_dir)

dataset_name = 'klal_gua_sgp_nmr.csv'

if os.listdir(datasets_dir) == []:
    print("No files found in the directory, creating datasets... \n")
    
    # Make the dataset for the individual NMR properties
    MachineLearning().make_empty_nuc_prop_df(datasets_dir, dataset_name)
else:
    print("Some files found in the directory, skipping... \n")
# Out:
# Dataset directory is: /Users/ettorebartalucci/Desktop/NONCOV/scratch/GenerateMLDataset/data/KLaL2/
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/GenerateMLDataset/data/KLaL2/
# No files found in the directory, creating datasets...
#
# The empty nuclear property dataset has been created and saved in: /Users/ettorebartalucci/Desktop/NONCOV/scratch/GenerateMLDataset/data/KLaL2/klal_gua_sgp_nmr.csv

# %%
# Display how the empty databases look like
nucprop = os.path.join(datasets_dir, dataset_name)
nucprop_df = pd.read_csv(nucprop)

# %%
# Individual nuclear properties
nucprop_df
# Out:
# Empty DataFrame
# Columns: [Molecule, Atom, x_coord, y_coord, z_coord, sigma_iso, sigma_xx, sigma_yy, sigma_zz, dia_sigma_xx, dia_sigma_yy, dia_sigma_zz, para_sigma_xx, para_sigma_yy, para_sigma_zz, sigma_11, sigma_22, sigma_33, s_tot_symmetry, span, skew]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# ### Process ORCA calculations with @ORCAAnalysis

# %%
# Provide files you want to process as input 
orca_output = input("Enter the path to the ORCA file you want to work with: ")
orca_output = OrcaAnalysis().convert_path(orca_output)
# Out:
# Enter the path to the ORCA file you want to work with:  KLaL_cation_pi_RCCE_opt.mpi8.out
# Normalized path using os.path: KLaL_cation_pi_RCCE_opt.mpi8.out

# %%
# Get the head of the file for saving files later
basename = os.path.basename(orca_output)
outname = basename.split('.')[0]

# %%
# Get a list of all the molecule names in the calculation, needed for ML later
list_molecules = OrcaAnalysis().extract_molecule_names(orca_output)
print(f'You have calculated the following molecules: {list_molecules}\n')
# Out:
# You have calculated the following molecules: ['KLaL_cation_pi_RCCE_opt_neg1p5.xyz', 'KLaL_cation_pi_RCCE_opt_neg1p4.xyz', 'KLaL_cation_pi_RCCE_opt_neg1p3.xyz', 'KLaL_cation_pi_RCCE_opt_neg1p2.xyz', 'KLaL_cation_pi_RCCE_opt_neg1p1.xyz', 'KLaL_cation_pi_RCCE_opt_neg1p0.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p9.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p8.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p7.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p6.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p5.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p4.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p3.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p2.xyz', 'KLaL_cation_pi_RCCE_opt_neg0p1.xyz', 'KLaL_cation_pi_RCCE_opt.xyz', 'KLaL_cation_pi_RCCE_opt_0p1.xyz', 'KLaL_cation_pi_RCCE_opt_0p2.xyz', 'KLaL_cation_pi_RCCE_opt_0p3.xyz', 'KLaL_cation_pi_RCCE_opt_0p4.xyz', 'KLaL_cation_pi_RCCE_opt_0p5.xyz', 'KLaL_cation_pi_RCCE_opt_0p6.xyz', 'KLaL_cation_pi_RCCE_opt_0p7.xyz', 'KLaL_cation_pi_RCCE_opt_0p8.xyz', 'KLaL_cation_pi_RCCE_opt_0p9.xyz', 'KLaL_cation_pi_RCCE_opt_1p0.xyz', 'KLaL_cation_pi_RCCE_opt_1p1.xyz', 'KLaL_cation_pi_RCCE_opt_1p2.xyz', 'KLaL_cation_pi_RCCE_opt_1p3.xyz', 'KLaL_cation_pi_RCCE_opt_1p4.xyz', 'KLaL_cation_pi_RCCE_opt_1p5.xyz', 'KLaL_cation_pi_RCCE_opt_1p6.xyz', 'KLaL_cation_pi_RCCE_opt_1p7.xyz', 'KLaL_cation_pi_RCCE_opt_1p8.xyz', 'KLaL_cation_pi_RCCE_opt_1p9.xyz', 'KLaL_cation_pi_RCCE_opt_2p0.xyz', 'KLaL_cation_pi_RCCE_opt_2p1.xyz', 'KLaL_cation_pi_RCCE_opt_2p2.xyz', 'KLaL_cation_pi_RCCE_opt_2p3.xyz', 'KLaL_cation_pi_RCCE_opt_2p4.xyz', 'KLaL_cation_pi_RCCE_opt_2p5.xyz', 'KLaL_cation_pi_RCCE_opt_2p6.xyz', 'KLaL_cation_pi_RCCE_opt_2p7.xyz', 'KLaL_cation_pi_RCCE_opt_2p8.xyz', 'KLaL_cation_pi_RCCE_opt_2p9.xyz', 'KLaL_cation_pi_RCCE_opt_3p0.xyz', 'KLaL_cation_pi_RCCE_opt_3p1.xyz', 'KLaL_cation_pi_RCCE_opt_3p2.xyz', 'KLaL_cation_pi_RCCE_opt_3p3.xyz', 'KLaL_cation_pi_RCCE_opt_3p4.xyz', 'KLaL_cation_pi_RCCE_opt_3p5.xyz', 'KLaL_cation_pi_RCCE_opt_3p6.xyz', 'KLaL_cation_pi_RCCE_opt_3p7.xyz', 'KLaL_cation_pi_RCCE_opt_3p8.xyz', 'KLaL_cation_pi_RCCE_opt_3p9.xyz', 'KLaL_cation_pi_RCCE_opt_4p0.xyz']

# %%
len(list_molecules)
# Out:
# 56

# %%
# Working with ORCA .out files

# Count how many sequential calculations have been done
n_jobs = OrcaAnalysis().count_jobs_number(orca_output)
print(f'Number of ORCA jobs in file: {n_jobs}\n')

# Compute size of the .out file and suggest Git LFS 
size_orca_output = os.path.getsize(orca_output)
size_orca_output = size_orca_output/1e6
print(f'Size of ORCA file is: {size_orca_output} MB\n')

if n_jobs > 20:
    print(f'Careful, you are working with a possibly large output file of several GB\n')
    print(f'If using version controls consider setting up a .gitignore \n')

if size_orca_output > 1:
    print(f"Careful, you are working with a '{size_orca_output}' KB large file..\n")
    print(f'Set up a .gitignore or Git LFS before pushing to Git\n')

# Extract level of theory
lot_out = OrcaAnalysis().extract_level_of_theory(orca_output)
print(f'Level of theory for the NMR calculations is: {lot_out}\n')

# Split orca output in several subfiles for ease of handling (takes a while)
if n_jobs > 2:
    print('Your output file will be now spilt into subfiles. \n')
    #OrcaAnalysis().split_orca_output(scratch_dir, orca_output)

else:
    print("This is a one job file")
# Out:
# Number of ORCA jobs in file: 56
#
# Size of ORCA file is: 8669.30638 MB
#
# Careful, you are working with a possibly large output file of several GB
#
# If using version controls consider setting up a .gitignore
#
# Careful, you are working with a '8669.30638' KB large file..
#
# Set up a .gitignore or Git LFS before pushing to Git
#
# Level of theory for the NMR calculations is: Job started from odin1, running /scratch/bartalucci/KLaL_cation_pi_RCCE_opt__VnjacZ__113301/orca/orca
#
# Your output file will be now spilt into subfiles.

# %%
# Initialize variables for shielding tensor components

S_dia = []
S_para = []
S_tot = []
nuclear_identities = []
mayer_bo = []
nuc_coords = []

# Extract NMR data from each splitted file
for job_number in range (1, n_jobs+1): # split files = number of jobs
        
    #blockPrint()
    
    # Path to the splitted outputs from the .out MPI8 file
    orca_splitted_output = OrcaAnalysis().convert_path(os.path.join(scratch_dir, 'OrcaAnalysis/split_orca_output', f'splitted_orca_job{job_number}.out'))

    # Extract CSA data
    shielding_dia, shielding_para, shielding_tot, nucleus_info = OrcaAnalysis().extract_tensor_data(orca_splitted_output)

    # Here include j coupling extraction
    #-------------
    
    # Extract bond orders
    #bond_orders = OrcaAnalysis().extract_mayer_bond_order(orca_splitted_output)
    
    # Print the bond orders and their interacting nuclei
    #for nucleus, bonds in bond_orders.items():
    #    print(f"{nucleus}:")
    #    for interacting_nucleus, bond_order in bonds:
    #       print(f"  Bond with {interacting_nucleus}: {bond_order}")
    
    #enablePrint()
    
    coords = OrcaAnalysis().extract_xyz_coords(orca_splitted_output)
    
    # Append shielding tensor matrices (non-diagonalized) - all nuclei for each job iteration
    S_dia.append(shielding_dia)
    S_para.append(shielding_para)
    S_tot.append(shielding_tot)
    nuclear_identities.append(nucleus_info)
    
    # Append bond orders
    #mayer_bo.append(bond_orders)
    
    # Append coordinates
    nuc_coords.append(coords)
# Out:
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job1.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job2.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job3.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job4.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job5.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job6.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job7.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job8.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job9.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job10.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job11.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job12.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job13.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job14.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job15.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job16.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job17.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job18.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job19.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job20.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job21.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job22.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job23.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job24.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job25.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job26.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job27.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job28.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job29.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job30.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job31.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job32.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job33.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job34.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job35.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job36.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job37.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job38.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job39.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job40.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job41.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job42.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job43.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job44.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job45.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job46.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job47.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job48.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job49.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job50.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job51.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job52.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job53.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job54.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job55.out
# Normalized path using os.path: /Users/ettorebartalucci/Desktop/NONCOV/scratch/OrcaAnalysis/split_orca_output/splitted_orca_job56.out

# %%
S_dia
# Out:
# [{'Nucleus 3H :': [[-35.648, -28.977, -124.394],
#    [15.621, 24.423, 40.959],
#    [-17.604, 5.687, 21.365]],
#   'Nucleus 4H :': [[-31.673, -25.637, -82.878],
#    [11.235, 61.353, 91.874],
#    [-9.317, 4.406, 15.81]],
#   'Nucleus 7H :': [[-24.142, -9.919, -88.184],
#    [6.922, 80.487, -36.714],
#    [-13.383, -3.19, 45.034]],
#   'Nucleus 9H :': [[57.3, -0.853, -58.172],
#    [-4.996, 61.931, -19.44],
#    [1.51, 0.085, 36.057]],
#   'Nucleus 11H :': [[133.119, -1.012, -40.57],
#    [-10.002, 34.695, -28.655],
#    [8.892, 0.202, 52.952]],
#   'Nucleus 14H :': [[92.797, -1.415, -31.774],
#    [-15.07, 48.711, 47.104],
#    [4.895, -7.323, 22.612]],
#   'Nucleus 15H :': [[134.199, -0.513, -43.471],
#    [-17.409, 57.829, 8.278],
#    [17.157, -12.674, 37.782]],
#   'Nucleus 18H :': [[115.605, 25.009, -18.72],
#    [0.355, 78.227, -39.303],
#    [7.569, -7.643, 48.124]],
#   'Nucleus 20H :': [[78.566, 1.211, 6.948],
#    [4.051, 93.546, -49.304],
#    [-3.609, 1.025, 45.431]],
#   'Nucleus 22H :': [[107.568, -22.067, 52.801],
#    [9.344, 63.308, -30.87],
#    [-12.199, -1.295, 35.441]],
#   'Nucleus 29H :': [[114.785, -0.082, 92.521],
#    [22.88, 24.93, 4.347],
#    [-21.991, -5.266, 20.01]],
#   'Nucleus 30H :': [[75.278, -11.478, 75.317],
#    [19.599, 51.736, 28.1],
#    [-6.517, -3.695, 18.218]],
#   'Nucleus 33H :': [[114.678, -0.743, 83.071],
#    [-19.9, 8.151, -26.886],
#    [-18.711, 3.294, 39.704]],
#   'Nucleus 35H :': [[24.19, -4.066, 70.059],
#    [-56.246, 30.938, -37.507],
#    [2.187, 0.431, 31.364]],
#   'Nucleus 37H :': [[-71.13, 16.144, 61.829],
#    [-22.105, 52.247, -72.179],
#    [17.066, -1.49, 50.498]],
#   'Nucleus 40H :': [[-61.43, 45.207, 65.747],
#    [16.225, 20.404, 46.17],
#    [4.487, 10.35, 24.46]],
#   'Nucleus 41H :': [[-99.88, 28.578, 87.075],
#    [13.837, -25.823, -7.551],
#    [-1.601, 316.302, 13.033],
#    [3.772, 2.79, 250.091]],
#   'Nucleus 25C :': [[235.67, 3.471, -54.733],
#    [6.44, 282.868, -1.349],
#    [-9.492, -0.445, 266.666]],
#   'Nucleus 28C :': [[304.701, 11.637, 78.922],
#    [38.094, 263.824, -17.016],
#    [-6.501, -14.131, 253.058]],
#   'Nucleus 31C :': [[218.699, -13.692, 64.278],
#    [-6.653, 264.983, -26.931],
#    [5.966, 4.952, 269.986]],
#   'Nucleus 32C :': [[270.927, -8.077, 88.987],
#    [7.749, 267.914, -58.608],
#    [-3.45, -7.678, 265.344]],
#   'Nucleus 34C :': [[246.634, -18.476, 88.595],
#    [-24.092, 262.98, -41.979],
#    [-2.247, 1.767, 269.222]],
#   'Nucleus 36C :': [[217.211, -7.0, 87.544],
#    [-23.279, 278.824, -44.597],
#    [1.695, 6.2, 265.044]],
#   'Nucleus 38C :': [[261.738, 24.324, 80.753],
#    [15.799, 323.131, -49.389],
#    [-13.388, -9.883, 267.445]],
#   'Nucleus 39C :': [[160.259, 24.763, 50.175],
#    [41.445, 198.106, 26.944],
#    [-1.72, 20.047, 251.318]],
#   'Nucleus 42C :': [[226.294, 28.112, -6.763],
#    [-4.841, 200.802, -39.26],
#    [2.172, -3.643, 270.103]],
#   'Nucleus 43C :': [[174.86, 33.472, 7.91],
#    [3.369, 222.16, -50.905],
#    [3.04, -6.376, 269.058]],
#   'Nucleus 45C :': [[225.825, -2.02, -1.465],
#    [19.199, 220.37, -61.348],
#    [5.201, -2.532, 262.735]],
#   'Nucleus 47C :': [[194.866, -39.468, -30.226],
#    [26.78, 233.465, -43.707],
#    [1.032, -9.551, 267.233]],
#   'Nucleus 49C :': [[219.267, -22.573, 0.249],
#    [18.175, 259.106, 6.167],
#    [0.686, -11.466, 258.934]],
#   'Nucleus 50C :': [[218.204, 33.75, 23.296],
#    [5.998, 137.914, -30.32],
#    [3.889, 2.117, 257.901]],
#   'Nucleus 51C :': [[200.3, 19.638, 128.596],
#    [7.003, 275.192, -33.965],
#    [-2.282, -4.015, 255.641]],
#   'Nucleus 57C :': [[250.573, 7.26, -44.871],
#    [-5.171, 275.715, -41.552],
#    [-8.622, 1.943, 268.206]],
#   'Nucleus 52N :': [[349.418, 22.687, -33.446],
#    [24.306, 374.914, -54.718],
#    [4.003, 6.126, 330.389]],
#   'Nucleus 54N :': [[208.076, -3.296, -55.925],
#    [-22.201, 327.041, -48.462],
#    [-9.714, -5.235, 334.703]],
#   'Nucleus 59N :': [[389.845, 0.574, -5.925],
#    [-18.499, 333.681, -27.854],
#    [-15.135, 4.341, 334.444]]}]

# %%
# Get all the data that are not pairwise
data = []

# Loop through the number of jobs and get each molecule, each job has a different one
for job_number in range(0, n_jobs):
    molecule_name = list_molecules[job_number]
    
    # Process each job for S_tot
    shielding_dict = S_tot[job_number]
    if isinstance(shielding_dict, dict):
        for nucleus_index, (nucleus_key, tensor) in enumerate(shielding_dict.items()):
            shielding_tensor, s_iso, diagonal_mehring, eigenvals, eigenvecs, symmetry, span, skew = NMRFunctions().diagonalize_tensor(tensor)
            
            sigma_xx = eigenvals[0]
            sigma_yy = eigenvals[1]
            sigma_zz = eigenvals[2]
            
            sigma_11 = diagonal_mehring[0][0]
            sigma_22 = diagonal_mehring[1][1]
            sigma_33 = diagonal_mehring[2][2]
            
            # Extract coordinates and identities for the current nucleus
            nuc_id = nuclear_identities[job_number][nucleus_index]
            
            # Handle different structures of nuc_coords
            coords = nuc_coords[job_number][nucleus_index]
            if len(coords) >= 3:
                x_coord = coords[1]
                y_coord = coords[2]
                z_coord = coords[3]
            else:
                x_coord = y_coord = z_coord = None  

            # Collect the data for this nucleus
            row_data = {
                'Molecule': molecule_name,
                'Atom': nuc_id,
                'x_coord': x_coord,
                'y_coord': y_coord,
                'z_coord': z_coord,
                'sigma_iso': s_iso,
                'sigma_xx': sigma_xx,
                'sigma_yy': sigma_yy,
                'sigma_zz': sigma_zz,
                'dia_sigma_xx': None,  
                'dia_sigma_yy': None,
                'dia_sigma_zz': None,
                'para_sigma_xx': None,  
                'para_sigma_yy': None,
                'para_sigma_zz': None,
                'sigma_11' : sigma_11,
                'sigma_22' : sigma_22,
                'sigma_33' : sigma_33,
                's_tot_symmetry' : symmetry,
                'span' : span,
                'skew' : skew
            }
            data.append(row_data)

    # After collecting data from S_tot, update with data from S_dia
    shielding_dict = S_dia[job_number]
    if isinstance(shielding_dict, dict):
        for nucleus_index, (nucleus_key, tensor) in enumerate(shielding_dict.items()):
            dia_shielding_tensor, dia_s_iso, dia_diagonal_mehring, dia_eigenvals, dia_eigenvecs, dia_symmetry, dia_span, dia_skew = NMRFunctions().diagonalize_tensor(tensor)

            dia_sigma_xx = dia_eigenvals[0]
            dia_sigma_yy = dia_eigenvals[1]
            dia_sigma_zz = dia_eigenvals[2]

            # Update the existing row_data with dia_sigma values
            for row in data:
                if row['Molecule'] == molecule_name and row['Atom'] == nucleus_key:
                    row.update({
                        'dia_sigma_xx': dia_sigma_xx,
                        'dia_sigma_yy': dia_sigma_yy,
                        'dia_sigma_zz': dia_sigma_zz
                    })

    # After collecting data from S_dia, update with data from S_para
    shielding_dict = S_para[job_number]
    if isinstance(shielding_dict, dict):
        for nucleus_index, (nucleus_key, tensor) in enumerate(shielding_dict.items()):
            para_shielding_tensor, para_s_iso, para_diagonal_mehring, para_eigenvals, para_eigenvecs, para_symmetry, para_span, para_skew = NMRFunctions().diagonalize_tensor(tensor)
            
            para_sigma_xx = para_eigenvals[0]
            para_sigma_yy = para_eigenvals[1]
            para_sigma_zz = para_eigenvals[2]

            # Update the existing row_data with para_sigma values
            for row in data:
                if row['Molecule'] == molecule_name and row['Atom'] == nucleus_key:
                    row.update({
                        'para_sigma_xx': para_sigma_xx,
                        'para_sigma_yy': para_sigma_yy,
                        'para_sigma_zz': para_sigma_zz
                    })

# Convert the list of rows to a DataFrame
datadf = pd.DataFrame(data)

# Concatenate with the existing DataFrame
nucprop_df = pd.concat([nucprop_df, datadf], ignore_index=True)

# Save the updated DataFrame to a CSV file
nucprop_df.to_csv(nucprop, index=False)

# Display the updated DataFrame
nucprop_df
# Out:
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[31.731  1.296 -5.381]
#  [-0.843 23.606 -0.677]
#  [-3.535 -1.344 27.096]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[31.731 -0.843 -3.535]
#  [ 1.296 23.606 -1.344]
#  [-5.381 -0.677 27.096]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[31.731   0.2265 -4.458 ]
#  [ 0.2265 23.606  -1.0105]
#  [-4.458  -1.0105 27.096 ]]
#
# Antisymmetric tensor is.
# [[ 0.      1.0695 -0.923 ]
#  [-1.0695  0.      0.3335]
#  [ 0.923  -0.3335  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [34.49 24.83 23.12], Eigenvectors are:
# [[ 0.85  0.48  0.22]
#  [ 0.07 -0.51  0.86]
#  [-0.52  0.72  0.46]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [23.12 24.83 34.49]
#  and of eigenvectors is:
# [[ 0.22  0.48  0.85]
#  [ 0.86 -0.51  0.07]
#  [ 0.46  0.72 -0.52]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[34.49  0.    0.  ]
#  [ 0.   24.83  0.  ]
#  [ 0.    0.   23.12]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 27.48 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[23.12  0.    0.  ]
#  [ 0.   24.83  0.  ]
#  [ 0.    0.   34.49]]
#
# where:
#  σ_11:23.12
#  σ_22:24.83
#  σ_33:34.49
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [ 0.85  0.07 -0.52]
# Eigenvector row 2: [ 0.48 -0.51  0.72]
# Eigenvector row 3: [0.22 0.86 0.46]
# 180 degrees rotation results in the tensor:
# [[27.096 -1.344 -3.535]
#  [-0.677 23.606 -0.843]
#  [-5.381  1.296 31.731]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 11.37
#
# Skew is: -0.7
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[31.731  1.296 -5.381]
#  [-0.843 23.606 -0.677]
#  [-3.535 -1.344 27.096]]
#
# Isotropic shielding: 27.48
#
# Mehring:
# [[23.12  0.    0.  ]
#  [ 0.   24.83  0.  ]
#  [ 0.    0.   34.49]]
#
# Unsorted Eigenvals:
# [34.49 24.83 23.12]
#
# Span is: 11.37
#
# Skew is: -0.7
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[ 2.5815e+01 -2.4170e+00 -1.4320e+00]
#  [-8.5400e-01  2.9134e+01 -2.9260e+00]
#  [-2.1690e+00 -2.8000e-02  2.5847e+01]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[ 2.5815e+01 -8.5400e-01 -2.1690e+00]
#  [-2.4170e+00  2.9134e+01 -2.8000e-02]
#  [-1.4320e+00 -2.9260e+00  2.5847e+01]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[25.815  -1.6355 -1.8005]
#  [-1.6355 29.134  -1.477 ]
#  [-1.8005 -1.477  25.847 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.7815  0.3685]
#  [ 0.7815  0.     -1.449 ]
#  [-0.3685  1.449   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [23.21 27.63 29.96], Eigenvectors are:
# [[ 0.67  0.69  0.28]
#  [ 0.35  0.04 -0.94]
#  [ 0.65 -0.73  0.22]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [23.21 27.63 29.96]
#  and of eigenvectors is:
# [[ 0.67  0.69  0.28]
#  [ 0.35  0.04 -0.94]
#  [ 0.65 -0.73  0.22]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[23.21  0.    0.  ]
#  [ 0.   27.63  0.  ]
#  [ 0.    0.   29.96]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 26.93 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[23.21  0.    0.  ]
#  [ 0.   27.63  0.  ]
#  [ 0.    0.   29.96]]
#
# where:
#  σ_11:23.21
#  σ_22:27.63
#  σ_33:29.96
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [0.67 0.35 0.65]
# Eigenvector row 2: [ 0.69  0.04 -0.73]
# Eigenvector row 3: [ 0.28 -0.94  0.22]
# 180 degrees rotation results in the tensor:
# [[ 2.5847e+01 -2.8000e-02 -2.1690e+00]
#  [-2.9260e+00  2.9134e+01 -8.5400e-01]
#  [-1.4320e+00 -2.4170e+00  2.5815e+01]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 6.75
#
# Skew is: 0.31
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[ 2.5815e+01 -2.4170e+00 -1.4320e+00]
#  [-8.5400e-01  2.9134e+01 -2.9260e+00]
#  [-2.1690e+00 -2.8000e-02  2.5847e+01]]
#
# Isotropic shielding: 26.93
#
# Mehring:
# [[23.21  0.    0.  ]
#  [ 0.   27.63  0.  ]
#  [ 0.    0.   29.96]]
#
# Unsorted Eigenvals:
# [23.21 27.63 29.96]
#
# Span is: 6.75
#
# Skew is: 0.31
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[22.943  2.467 -0.639]
#  [ 4.018 25.718  2.693]
#  [ 2.032  4.011 23.98 ]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[22.943  4.018  2.032]
#  [ 2.467 25.718  4.011]
#  [-0.639  2.693 23.98 ]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[22.943   3.2425  0.6965]
#  [ 3.2425 25.718   3.352 ]
#  [ 0.6965  3.352  23.98  ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.7755 -1.3355]
#  [ 0.7755  0.     -0.659 ]
#  [ 1.3355  0.659   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [29.69 20.16 22.79], Eigenvectors are:
# [[-0.42 -0.63 -0.65]
#  [-0.76  0.64 -0.13]
#  [-0.5  -0.44  0.75]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [20.16 22.79 29.69]
#  and of eigenvectors is:
# [[-0.63 -0.65 -0.42]
#  [ 0.64 -0.13 -0.76]
#  [-0.44  0.75 -0.5 ]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[29.69  0.    0.  ]
#  [ 0.   20.16  0.  ]
#  [ 0.    0.   22.79]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 24.21 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[20.16  0.    0.  ]
#  [ 0.   22.79  0.  ]
#  [ 0.    0.   29.69]]
#
# where:
#  σ_11:20.16
#  σ_22:22.79
#  σ_33:29.69
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.42 -0.76 -0.5 ]
# Eigenvector row 2: [-0.63  0.64 -0.44]
# Eigenvector row 3: [-0.65 -0.13  0.75]
# 180 degrees rotation results in the tensor:
# [[23.98   4.011  2.032]
#  [ 2.693 25.718  4.018]
#  [-0.639  2.467 22.943]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 9.53
#
# Skew is: -0.45
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[22.943  2.467 -0.639]
#  [ 4.018 25.718  2.693]
#  [ 2.032  4.011 23.98 ]]
#
# Isotropic shielding: 24.21
#
# Mehring:
# [[20.16  0.    0.  ]
#  [ 0.   22.79  0.  ]
#  [ 0.    0.   29.69]]
#
# Unsorted Eigenvals:
# [29.69 20.16 22.79]
#
# Span is: 9.53
#
# Skew is: -0.45
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[23.004  2.982 -0.913]
#  [ 2.671 24.145  0.549]
#  [-1.05   0.561 27.115]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[23.004  2.671 -1.05 ]
#  [ 2.982 24.145  0.561]
#  [-0.913  0.549 27.115]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[23.004   2.8265 -0.9815]
#  [ 2.8265 24.145   0.555 ]
#  [-0.9815  0.555  27.115 ]]
#
# Antisymmetric tensor is.
# [[ 0.      0.1555  0.0685]
#  [-0.1555  0.     -0.006 ]
#  [-0.0685  0.006   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [20.5  26.42 27.34], Eigenvectors are:
# [[-0.77  0.59 -0.26]
#  [ 0.62  0.78 -0.06]
#  [-0.17  0.21  0.96]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [20.5  26.42 27.34]
#  and of eigenvectors is:
# [[-0.77  0.59 -0.26]
#  [ 0.62  0.78 -0.06]
#  [-0.17  0.21  0.96]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[20.5   0.    0.  ]
#  [ 0.   26.42  0.  ]
#  [ 0.    0.   27.34]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 24.75 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[20.5   0.    0.  ]
#  [ 0.   26.42  0.  ]
#  [ 0.    0.   27.34]]
#
# where:
#  σ_11:20.5
#  σ_22:26.42
#  σ_33:27.34
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.77  0.62 -0.17]
# Eigenvector row 2: [0.59 0.78 0.21]
# Eigenvector row 3: [-0.26 -0.06  0.96]
# 180 degrees rotation results in the tensor:
# [[27.115  0.561 -1.05 ]
#  [ 0.549 24.145  2.671]
#  [-0.913  2.982 23.004]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 6.84
#
# Skew is: 0.73
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[23.004  2.982 -0.913]
#  [ 2.671 24.145  0.549]
#  [-1.05   0.561 27.115]]
#
# Isotropic shielding: 24.75
#
# Mehring:
# [[20.5   0.    0.  ]
#  [ 0.   26.42  0.  ]
#  [ 0.    0.   27.34]]
#
# Unsorted Eigenvals:
# [20.5  26.42 27.34]
#
# Span is: 6.84
#
# Skew is: 0.73
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[23.692  3.864  0.663]
#  [ 4.855 25.687 -0.695]
#  [-2.292 -2.604 23.095]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[23.692  4.855 -2.292]
#  [ 3.864 25.687 -2.604]
#  [ 0.663 -0.695 23.095]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[23.692   4.3595 -0.8145]
#  [ 4.3595 25.687  -1.6495]
#  [-0.8145 -1.6495 23.095 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.4955  1.4775]
#  [ 0.4955  0.      0.9545]
#  [-1.4775 -0.9545  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [29.66 20.16 22.66], Eigenvectors are:
# [[-0.59 -0.75  0.28]
#  [-0.76  0.64  0.11]
#  [ 0.26  0.15  0.95]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [20.16 22.66 29.66]
#  and of eigenvectors is:
# [[-0.75  0.28 -0.59]
#  [ 0.64  0.11 -0.76]
#  [ 0.15  0.95  0.26]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[29.66  0.    0.  ]
#  [ 0.   20.16  0.  ]
#  [ 0.    0.   22.66]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 24.16 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[20.16  0.    0.  ]
#  [ 0.   22.66  0.  ]
#  [ 0.    0.   29.66]]
#
# where:
#  σ_11:20.16
#  σ_22:22.66
#  σ_33:29.66
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.59 -0.76  0.26]
# Eigenvector row 2: [-0.75  0.64  0.15]
# Eigenvector row 3: [0.28 0.11 0.95]
# 180 degrees rotation results in the tensor:
# [[23.095 -2.604 -2.292]
#  [-0.695 25.687  4.855]
#  [ 0.663  3.864 23.692]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 9.5
#
# Skew is: -0.47
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[23.692  3.864  0.663]
#  [ 4.855 25.687 -0.695]
#  [-2.292 -2.604 23.095]]
#
# Isotropic shielding: 24.16
#
# Mehring:
# [[20.16  0.    0.  ]
#  [ 0.   22.66  0.  ]
#  [ 0.    0.   29.66]]
#
# Unsorted Eigenvals:
# [29.66 20.16 22.66]
#
# Span is: 9.5
#
# Skew is: -0.47
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[23.71  -1.979  0.239]
#  [-1.528 28.718  2.525]
#  [ 1.004 -0.49  26.487]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[23.71  -1.528  1.004]
#  [-1.979 28.718 -0.49 ]
#  [ 0.239  2.525 26.487]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[23.71   -1.7535  0.6215]
#  [-1.7535 28.718   1.0175]
#  [ 0.6215  1.0175 26.487 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.2255 -0.3825]
#  [ 0.2255  0.      1.5075]
#  [ 0.3825 -1.5075  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [22.92 29.48 26.51], Eigenvectors are:
# [[ 0.91  0.25  0.32]
#  [ 0.32 -0.93 -0.18]
#  [-0.25 -0.26  0.93]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [22.92 26.51 29.48]
#  and of eigenvectors is:
# [[ 0.91  0.32  0.25]
#  [ 0.32 -0.18 -0.93]
#  [-0.25  0.93 -0.26]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[22.92  0.    0.  ]
#  [ 0.   29.48  0.  ]
#  [ 0.    0.   26.51]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 26.3 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[22.92  0.    0.  ]
#  [ 0.   26.51  0.  ]
#  [ 0.    0.   29.48]]
#
# where:
#  σ_11:22.92
#  σ_22:26.51
#  σ_33:29.48
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [ 0.91  0.32 -0.25]
# Eigenvector row 2: [ 0.25 -0.93 -0.26]
# Eigenvector row 3: [ 0.32 -0.18  0.93]
# 180 degrees rotation results in the tensor:
# [[26.487 -0.49   1.004]
#  [ 2.525 28.718 -1.528]
#  [ 0.239 -1.979 23.71 ]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 6.56
#
# Skew is: 0.1
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[23.71  -1.979  0.239]
#  [-1.528 28.718  2.525]
#  [ 1.004 -0.49  26.487]]
#
# Isotropic shielding: 26.3
#
# Mehring:
# [[22.92  0.    0.  ]
#  [ 0.   26.51  0.  ]
#  [ 0.    0.   29.48]]
#
# Unsorted Eigenvals:
# [22.92 29.48 26.51]
#
# Span is: 6.56
#
# Skew is: 0.1
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[27.76  -0.053  5.679]
#  [-1.407 23.757 -0.413]
#  [ 3.717  1.287 31.58 ]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[27.76  -1.407  3.717]
#  [-0.053 23.757  1.287]
#  [ 5.679 -0.413 31.58 ]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[27.76  -0.73   4.698]
#  [-0.73  23.757  0.437]
#  [ 4.698  0.437 31.58 ]]
#
# Antisymmetric tensor is.
# [[ 0.     0.677  0.981]
#  [-0.677  0.    -0.85 ]
#  [-0.981  0.85   0.   ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [34.74 25.13 23.23], Eigenvectors are:
# [[-0.56  0.7   0.44]
#  [ 0.   -0.53  0.85]
#  [-0.83 -0.48 -0.29]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [23.23 25.13 34.74]
#  and of eigenvectors is:
# [[ 0.44  0.7  -0.56]
#  [ 0.85 -0.53  0.  ]
#  [-0.29 -0.48 -0.83]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[34.74  0.    0.  ]
#  [ 0.   25.13  0.  ]
#  [ 0.    0.   23.23]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 27.7 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[23.23  0.    0.  ]
#  [ 0.   25.13  0.  ]
#  [ 0.    0.   34.74]]
#
# where:
#  σ_11:23.23
#  σ_22:25.13
#  σ_33:34.74
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.56  0.   -0.83]
# Eigenvector row 2: [ 0.7  -0.53 -0.48]
# Eigenvector row 3: [ 0.44  0.85 -0.29]
# 180 degrees rotation results in the tensor:
# [[31.58   1.287  3.717]
#  [-0.413 23.757 -1.407]
#  [ 5.679 -0.053 27.76 ]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 11.51
#
# Skew is: -0.67
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[27.76  -0.053  5.679]
#  [-1.407 23.757 -0.413]
#  [ 3.717  1.287 31.58 ]]
#
# Isotropic shielding: 27.7
#
# Mehring:
# [[23.23  0.    0.  ]
#  [ 0.   25.13  0.  ]
#  [ 0.    0.   34.74]]
#
# Unsorted Eigenvals:
# [34.74 25.13 23.23]
#
# Span is: 11.51
#
# Skew is: -0.67
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[23.272 -1.996 -1.298]
#  [-1.92  22.375  3.089]
#  [-0.969  3.296 24.865]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[23.272 -1.92  -0.969]
#  [-1.996 22.375  3.296]
#  [-1.298  3.089 24.865]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[23.272  -1.958  -1.1335]
#  [-1.958  22.375   3.1925]
#  [-1.1335  3.1925 24.865 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.038  -0.1645]
#  [ 0.038   0.     -0.1035]
#  [ 0.1645  0.1035  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [27.96 22.7  19.86], Eigenvectors are:
# [[-0.41  0.85 -0.32]
#  [ 0.56 -0.05 -0.83]
#  [ 0.72  0.52  0.46]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [19.86 22.7  27.96]
#  and of eigenvectors is:
# [[-0.32  0.85 -0.41]
#  [-0.83 -0.05  0.56]
#  [ 0.46  0.52  0.72]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[27.96  0.    0.  ]
#  [ 0.   22.7   0.  ]
#  [ 0.    0.   19.86]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 23.51 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[19.86  0.    0.  ]
#  [ 0.   22.7   0.  ]
#  [ 0.    0.   27.96]]
#
# where:
#  σ_11:19.86
#  σ_22:22.7
#  σ_33:27.96
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.41  0.56  0.72]
# Eigenvector row 2: [ 0.85 -0.05  0.52]
# Eigenvector row 3: [-0.32 -0.83  0.46]
# 180 degrees rotation results in the tensor:
# [[24.865  3.296 -0.969]
#  [ 3.089 22.375 -1.92 ]
#  [-1.298 -1.996 23.272]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 8.1
#
# Skew is: -0.3
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[23.272 -1.996 -1.298]
#  [-1.92  22.375  3.089]
#  [-0.969  3.296 24.865]]
#
# Isotropic shielding: 23.51
#
# Mehring:
# [[19.86  0.    0.  ]
#  [ 0.   22.7   0.  ]
#  [ 0.    0.   27.96]]
#
# Unsorted Eigenvals:
# [27.96 22.7  19.86]
#
# Span is: 8.1
#
# Skew is: -0.3
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[25.893 -0.55   0.605]
#  [-0.566 21.939  2.814]
#  [ 0.655  2.18  23.523]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[25.893 -0.566  0.655]
#  [-0.55  21.939  2.18 ]
#  [ 0.605  2.814 23.523]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[25.893 -0.558  0.63 ]
#  [-0.558 21.939  2.497]
#  [ 0.63   2.497 23.523]]
#
# Antisymmetric tensor is.
# [[ 0.     0.008 -0.025]
#  [-0.008  0.     0.317]
#  [ 0.025 -0.317  0.   ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [20.   26.05 25.31], Eigenvectors are:
# [[-0.14 -0.96 -0.24]
#  [-0.8  -0.04  0.6 ]
#  [ 0.59 -0.28  0.76]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [20.   25.31 26.05]
#  and of eigenvectors is:
# [[-0.14 -0.24 -0.96]
#  [-0.8   0.6  -0.04]
#  [ 0.59  0.76 -0.28]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[20.    0.    0.  ]
#  [ 0.   26.05  0.  ]
#  [ 0.    0.   25.31]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 23.79 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[20.    0.    0.  ]
#  [ 0.   25.31  0.  ]
#  [ 0.    0.   26.05]]
#
# where:
#  σ_11:20.0
#  σ_22:25.31
#  σ_33:26.05
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.14 -0.8   0.59]
# Eigenvector row 2: [-0.96 -0.04 -0.28]
# Eigenvector row 3: [-0.24  0.6   0.76]
# 180 degrees rotation results in the tensor:
# [[23.523  2.18   0.655]
#  [ 2.814 21.939 -0.566]
#  [ 0.605 -0.55  25.893]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 6.05
#
# Skew is: 0.75
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[25.893 -0.55   0.605]
#  [-0.566 21.939  2.814]
#  [ 0.655  2.18  23.523]]
#
# Isotropic shielding: 23.79
#
# Mehring:
# [[20.    0.    0.  ]
#  [ 0.   25.31  0.  ]
#  [ 0.    0.   26.05]]
#
# Unsorted Eigenvals:
# [20.   26.05 25.31]
#
# Span is: 6.05
#
# Skew is: 0.75
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[23.233  0.229  0.319]
#  [ 0.131 22.523  3.861]
#  [-0.034  4.071 25.577]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[23.233  0.131 -0.034]
#  [ 0.229 22.523  4.071]
#  [ 0.319  3.861 25.577]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[23.233   0.18    0.1425]
#  [ 0.18   22.523   3.966 ]
#  [ 0.1425  3.966  25.577 ]]
#
# Antisymmetric tensor is.
# [[ 0.      0.049   0.1765]
#  [-0.049   0.     -0.105 ]
#  [-0.1765  0.105   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [28.31 23.22 19.8 ], Eigenvectors are:
# [[ 0.04  1.    0.02]
#  [ 0.57 -0.01 -0.82]
#  [ 0.82 -0.05  0.57]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [19.8  23.22 28.31]
#  and of eigenvectors is:
# [[ 0.02  1.    0.04]
#  [-0.82 -0.01  0.57]
#  [ 0.57 -0.05  0.82]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[28.31  0.    0.  ]
#  [ 0.   23.22  0.  ]
#  [ 0.    0.   19.8 ]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 23.78 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[19.8   0.    0.  ]
#  [ 0.   23.22  0.  ]
#  [ 0.    0.   28.31]]
#
# where:
#  σ_11:19.8
#  σ_22:23.22
#  σ_33:28.31
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [0.04 0.57 0.82]
# Eigenvector row 2: [ 1.   -0.01 -0.05]
# Eigenvector row 3: [ 0.02 -0.82  0.57]
# 180 degrees rotation results in the tensor:
# [[25.577  4.071 -0.034]
#  [ 3.861 22.523  0.131]
#  [ 0.319  0.229 23.233]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 8.51
#
# Skew is: -0.2
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[23.233  0.229  0.319]
#  [ 0.131 22.523  3.861]
#  [-0.034  4.071 25.577]]
#
# Isotropic shielding: 23.78
#
# Mehring:
# [[19.8   0.    0.  ]
#  [ 0.   23.22  0.  ]
#  [ 0.    0.   28.31]]
#
# Unsorted Eigenvals:
# [28.31 23.22 19.8 ]
#
# Span is: 8.51
#
# Skew is: -0.2
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[31.443 -1.042 -5.306]
#  [ 0.984 23.549  0.607]
#  [-3.878  1.442 27.077]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[31.443  0.984 -3.878]
#  [-1.042 23.549  1.442]
#  [-5.306  0.607 27.077]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[ 3.1443e+01 -2.9000e-02 -4.5920e+00]
#  [-2.9000e-02  2.3549e+01  1.0245e+00]
#  [-4.5920e+00  1.0245e+00  2.7077e+01]]
#
# Antisymmetric tensor is.
# [[ 0.     -1.013  -0.714 ]
#  [ 1.013   0.     -0.4175]
#  [ 0.714   0.4175  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [34.37 24.76 22.94], Eigenvectors are:
# [[-0.84  0.47  0.27]
#  [ 0.05  0.56 -0.82]
#  [ 0.54  0.68  0.5 ]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [22.94 24.76 34.37]
#  and of eigenvectors is:
# [[ 0.27  0.47 -0.84]
#  [-0.82  0.56  0.05]
#  [ 0.5   0.68  0.54]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[34.37  0.    0.  ]
#  [ 0.   24.76  0.  ]
#  [ 0.    0.   22.94]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 27.36 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[22.94  0.    0.  ]
#  [ 0.   24.76  0.  ]
#  [ 0.    0.   34.37]]
#
# where:
#  σ_11:22.94
#  σ_22:24.76
#  σ_33:34.37
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.84  0.05  0.54]
# Eigenvector row 2: [0.47 0.56 0.68]
# Eigenvector row 3: [ 0.27 -0.82  0.5 ]
# 180 degrees rotation results in the tensor:
# [[27.077  1.442 -3.878]
#  [ 0.607 23.549  0.984]
#  [-5.306 -1.042 31.443]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 11.43
#
# Skew is: -0.68
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[31.443 -1.042 -5.306]
#  [ 0.984 23.549  0.607]
#  [-3.878  1.442 27.077]]
#
# Isotropic shielding: 27.36
#
# Mehring:
# [[22.94  0.    0.  ]
#  [ 0.   24.76  0.  ]
#  [ 0.    0.   34.37]]
#
# Unsorted Eigenvals:
# [34.37 24.76 22.94]
#
# Span is: 11.43
#
# Skew is: -0.68
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[25.682  2.633 -1.33 ]
#  [ 1.087 29.297  2.683]
#  [-2.31  -0.208 26.064]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[25.682  1.087 -2.31 ]
#  [ 2.633 29.297 -0.208]
#  [-1.33   2.683 26.064]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[25.682   1.86   -1.82  ]
#  [ 1.86   29.297   1.2375]
#  [-1.82    1.2375 26.064 ]]
#
# Antisymmetric tensor is.
# [[ 0.      0.773   0.49  ]
#  [-0.773   0.      1.4455]
#  [-0.49   -1.4455  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [23.23 27.67 30.14], Eigenvectors are:
# [[ 0.71 -0.61  0.33]
#  [-0.34  0.11  0.93]
#  [ 0.61  0.78  0.13]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [23.23 27.67 30.14]
#  and of eigenvectors is:
# [[ 0.71 -0.61  0.33]
#  [-0.34  0.11  0.93]
#  [ 0.61  0.78  0.13]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[23.23  0.    0.  ]
#  [ 0.   27.67  0.  ]
#  [ 0.    0.   30.14]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 27.01 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[23.23  0.    0.  ]
#  [ 0.   27.67  0.  ]
#  [ 0.    0.   30.14]]
#
# where:
#  σ_11:23.23
#  σ_22:27.67
#  σ_33:30.14
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [ 0.71 -0.34  0.61]
# Eigenvector row 2: [-0.61  0.11  0.78]
# Eigenvector row 3: [0.33 0.93 0.13]
# 180 degrees rotation results in the tensor:
# [[26.064 -0.208 -2.31 ]
#  [ 2.683 29.297  1.087]
#  [-1.33   2.633 25.682]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 6.91
#
# Skew is: 0.29
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[25.682  2.633 -1.33 ]
#  [ 1.087 29.297  2.683]
#  [-2.31  -0.208 26.064]]
#
# Isotropic shielding: 27.01
#
# Mehring:
# [[23.23  0.    0.  ]
#  [ 0.   27.67  0.  ]
#  [ 0.    0.   30.14]]
#
# Unsorted Eigenvals:
# [23.23 27.67 30.14]
#
# Span is: 6.91
#
# Skew is: 0.29
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[22.73  -2.394 -0.468]
#  [-4.009 25.524 -2.758]
#  [ 2.166 -3.964 23.636]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[22.73  -4.009  2.166]
#  [-2.394 25.524 -3.964]
#  [-0.468 -2.758 23.636]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[22.73   -3.2015  0.849 ]
#  [-3.2015 25.524  -3.361 ]
#  [ 0.849  -3.361  23.636 ]]
#
# Antisymmetric tensor is.
# [[ 0.      0.8075 -1.317 ]
#  [-0.8075  0.      0.603 ]
#  [ 1.317  -0.603   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [29.5  22.35 20.05], Eigenvectors are:
# [[-0.42  0.66  0.62]
#  [ 0.76 -0.12  0.64]
#  [-0.5  -0.74  0.45]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [20.05 22.35 29.5 ]
#  and of eigenvectors is:
# [[ 0.62  0.66 -0.42]
#  [ 0.64 -0.12  0.76]
#  [ 0.45 -0.74 -0.5 ]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[29.5   0.    0.  ]
#  [ 0.   22.35  0.  ]
#  [ 0.    0.   20.05]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 23.97 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[20.05  0.    0.  ]
#  [ 0.   22.35  0.  ]
#  [ 0.    0.   29.5 ]]
#
# where:
#  σ_11:20.05
#  σ_22:22.35
#  σ_33:29.5
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.42  0.76 -0.5 ]
# Eigenvector row 2: [ 0.66 -0.12 -0.74]
# Eigenvector row 3: [0.62 0.64 0.45]
# 180 degrees rotation results in the tensor:
# [[23.636 -3.964  2.166]
#  [-2.758 25.524 -4.009]
#  [-0.468 -2.394 22.73 ]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 9.45
#
# Skew is: -0.51
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[22.73  -2.394 -0.468]
#  [-4.009 25.524 -2.758]
#  [ 2.166 -3.964 23.636]]
#
# Isotropic shielding: 23.97
#
# Mehring:
# [[20.05  0.    0.  ]
#  [ 0.   22.35  0.  ]
#  [ 0.    0.   29.5 ]]
#
# Unsorted Eigenvals:
# [29.5  22.35 20.05]
#
# Span is: 9.45
#
# Skew is: -0.51
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[22.94  -3.135 -1.025]
#  [-2.569 23.687 -0.499]
#  [-1.084 -0.635 27.072]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[22.94  -2.569 -1.084]
#  [-3.135 23.687 -0.635]
#  [-1.025 -0.499 27.072]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[22.94   -2.852  -1.0545]
#  [-2.852  23.687  -0.567 ]
#  [-1.0545 -0.567  27.072 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.283   0.0295]
#  [ 0.283   0.      0.068 ]
#  [-0.0295 -0.068   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [20.24 26.13 27.33], Eigenvectors are:
# [[-0.75 -0.61 -0.27]
#  [-0.64  0.76  0.06]
#  [-0.17 -0.22  0.96]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [20.24 26.13 27.33]
#  and of eigenvectors is:
# [[-0.75 -0.61 -0.27]
#  [-0.64  0.76  0.06]
#  [-0.17 -0.22  0.96]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[20.24  0.    0.  ]
#  [ 0.   26.13  0.  ]
#  [ 0.    0.   27.33]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 24.57 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[20.24  0.    0.  ]
#  [ 0.   26.13  0.  ]
#  [ 0.    0.   27.33]]
#
# where:
#  σ_11:20.24
#  σ_22:26.13
#  σ_33:27.33
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.75 -0.64 -0.17]
# Eigenvector row 2: [-0.61  0.76 -0.22]
# Eigenvector row 3: [-0.27  0.06  0.96]
# 180 degrees rotation results in the tensor:
# [[27.072 -0.635 -1.084]
#  [-0.499 23.687 -2.569]
#  [-1.025 -3.135 22.94 ]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 7.09
#
# Skew is: 0.66
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[22.94  -3.135 -1.025]
#  [-2.569 23.687 -0.499]
#  [-1.084 -0.635 27.072]]
#
# Isotropic shielding: 24.57
#
# Mehring:
# [[20.24  0.    0.  ]
#  [ 0.   26.13  0.  ]
#  [ 0.    0.   27.33]]
#
# Unsorted Eigenvals:
# [20.24 26.13 27.33]
#
# Span is: 7.09
#
# Skew is: 0.66
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[23.614 -3.871  0.454]
#  [-4.89  25.58   0.733]
#  [-2.441  2.456 22.883]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[23.614 -4.89  -2.441]
#  [-3.871 25.58   2.456]
#  [ 0.454  0.733 22.883]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[23.614  -4.3805 -0.9935]
#  [-4.3805 25.58    1.5945]
#  [-0.9935  1.5945 22.883 ]]
#
# Antisymmetric tensor is.
# [[ 0.      0.5095  1.4475]
#  [-0.5095  0.     -0.8615]
#  [-1.4475  0.8615  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [29.6  20.09 22.39], Eigenvectors are:
# [[ 0.6  -0.77  0.24]
#  [-0.76 -0.64 -0.15]
#  [-0.27  0.09  0.96]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [20.09 22.39 29.6 ]
#  and of eigenvectors is:
# [[-0.77  0.24  0.6 ]
#  [-0.64 -0.15 -0.76]
#  [ 0.09  0.96 -0.27]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[29.6   0.    0.  ]
#  [ 0.   20.09  0.  ]
#  [ 0.    0.   22.39]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 24.03 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[20.09  0.    0.  ]
#  [ 0.   22.39  0.  ]
#  [ 0.    0.   29.6 ]]
#
# where:
#  σ_11:20.09
#  σ_22:22.39
#  σ_33:29.6
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [ 0.6  -0.76 -0.27]
# Eigenvector row 2: [-0.77 -0.64  0.09]
# Eigenvector row 3: [ 0.24 -0.15  0.96]
# 180 degrees rotation results in the tensor:
# [[22.883  2.456 -2.441]
#  [ 0.733 25.58  -4.89 ]
#  [ 0.454 -3.871 23.614]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 9.51
#
# Skew is: -0.52
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[23.614 -3.871  0.454]
#  [-4.89  25.58   0.733]
#  [-2.441  2.456 22.883]]
#
# Isotropic shielding: 24.03
#
# Mehring:
# [[20.09  0.    0.  ]
#  [ 0.   22.39  0.  ]
#  [ 0.    0.   29.6 ]]
#
# Unsorted Eigenvals:
# [29.6  20.09 22.39]
#
# Span is: 9.51
#
# Skew is: -0.52
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[24.572  2.235  0.444]
#  [ 2.042 29.405 -1.979]
#  [ 1.228  1.255 27.548]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[24.572  2.042  1.228]
#  [ 2.235 29.405  1.255]
#  [ 0.444 -1.979 27.548]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[24.572   2.1385  0.836 ]
#  [ 2.1385 29.405  -0.362 ]
#  [ 0.836  -0.362  27.548 ]]
#
# Antisymmetric tensor is.
# [[ 0.      0.0965 -0.392 ]
#  [-0.0965  0.     -1.617 ]
#  [ 0.392   1.617   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [23.55 30.22 27.75], Eigenvectors are:
# [[ 0.91 -0.35  0.21]
#  [-0.35 -0.94 -0.06]
#  [-0.22  0.02  0.97]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [23.55 27.75 30.22]
#  and of eigenvectors is:
# [[ 0.91  0.21 -0.35]
#  [-0.35 -0.06 -0.94]
#  [-0.22  0.97  0.02]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[23.55  0.    0.  ]
#  [ 0.   30.22  0.  ]
#  [ 0.    0.   27.75]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 27.17 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[23.55  0.    0.  ]
#  [ 0.   27.75  0.  ]
#  [ 0.    0.   30.22]]
#
# where:
#  σ_11:23.55
#  σ_22:27.75
#  σ_33:30.22
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [ 0.91 -0.35 -0.22]
# Eigenvector row 2: [-0.35 -0.94  0.02]
# Eigenvector row 3: [ 0.21 -0.06  0.97]
# 180 degrees rotation results in the tensor:
# [[27.548  1.255  1.228]
#  [-1.979 29.405  2.042]
#  [ 0.444  2.235 24.572]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 6.67
#
# Skew is: 0.26
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[24.572  2.235  0.444]
#  [ 2.042 29.405 -1.979]
#  [ 1.228  1.255 27.548]]
#
# Isotropic shielding: 27.17
#
# Mehring:
# [[23.55  0.    0.  ]
#  [ 0.   27.75  0.  ]
#  [ 0.    0.   30.22]]
#
# Unsorted Eigenvals:
# [23.55 30.22 27.75]
#
# Span is: 6.67
#
# Skew is: 0.26
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[ 2.7078e+01 -3.0000e-03  5.5630e+00]
#  [ 1.2900e+00  2.3536e+01  1.1100e-01]
#  [ 3.8900e+00 -1.4600e+00  3.1415e+01]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[ 2.7078e+01  1.2900e+00  3.8900e+00]
#  [-3.0000e-03  2.3536e+01 -1.4600e+00]
#  [ 5.5630e+00  1.1100e-01  3.1415e+01]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[27.078   0.6435  4.7265]
#  [ 0.6435 23.536  -0.6745]
#  [ 4.7265 -0.6745 31.415 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.6465  0.8365]
#  [ 0.6465  0.      0.7855]
#  [-0.8365 -0.7855  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [34.45 24.73 22.85], Eigenvectors are:
# [[-0.54 -0.68  0.5 ]
#  [ 0.02 -0.6  -0.8 ]
#  [-0.84  0.42 -0.34]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [22.85 24.73 34.45]
#  and of eigenvectors is:
# [[ 0.5  -0.68 -0.54]
#  [-0.8  -0.6   0.02]
#  [-0.34  0.42 -0.84]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[34.45  0.    0.  ]
#  [ 0.   24.73  0.  ]
#  [ 0.    0.   22.85]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 27.34 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[22.85  0.    0.  ]
#  [ 0.   24.73  0.  ]
#  [ 0.    0.   34.45]]
#
# where:
#  σ_11:22.85
#  σ_22:24.73
#  σ_33:34.45
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.54  0.02 -0.84]
# Eigenvector row 2: [-0.68 -0.6   0.42]
# Eigenvector row 3: [ 0.5  -0.8  -0.34]
# 180 degrees rotation results in the tensor:
# [[ 3.1415e+01 -1.4600e+00  3.8900e+00]
#  [ 1.1100e-01  2.3536e+01  1.2900e+00]
#  [ 5.5630e+00 -3.0000e-03  2.7078e+01]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 11.6
#
# Skew is: -0.67
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[ 2.7078e+01 -3.0000e-03  5.5630e+00]
#  [ 1.2900e+00  2.3536e+01  1.1100e-01]
#  [ 3.8900e+00 -1.4600e+00  3.1415e+01]]
#
# Isotropic shielding: 27.34
#
# Mehring:
# [[22.85  0.    0.  ]
#  [ 0.   24.73  0.  ]
#  [ 0.    0.   34.45]]
#
# Unsorted Eigenvals:
# [34.45 24.73 22.85]
#
# Span is: 11.6
#
# Skew is: -0.67
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[23.289  1.97  -1.114]
#  [ 1.924 22.603 -3.247]
#  [-0.789 -3.486 25.022]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[23.289  1.924 -0.789]
#  [ 1.97  22.603 -3.486]
#  [-1.114 -3.247 25.022]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[23.289   1.947  -0.9515]
#  [ 1.947  22.603  -3.3665]
#  [-0.9515 -3.3665 25.022 ]]
#
# Antisymmetric tensor is.
# [[ 0.      0.023  -0.1625]
#  [-0.023   0.      0.1195]
#  [ 0.1625 -0.1195  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [28.15 22.9  19.86], Eigenvectors are:
# [[-0.37 -0.87 -0.33]
#  [-0.57 -0.07  0.82]
#  [ 0.73 -0.5   0.47]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [19.86 22.9  28.15]
#  and of eigenvectors is:
# [[-0.33 -0.87 -0.37]
#  [ 0.82 -0.07 -0.57]
#  [ 0.47 -0.5   0.73]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[28.15  0.    0.  ]
#  [ 0.   22.9   0.  ]
#  [ 0.    0.   19.86]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 23.64 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[19.86  0.    0.  ]
#  [ 0.   22.9   0.  ]
#  [ 0.    0.   28.15]]
#
# where:
#  σ_11:19.86
#  σ_22:22.9
#  σ_33:28.15
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.37 -0.57  0.73]
# Eigenvector row 2: [-0.87 -0.07 -0.5 ]
# Eigenvector row 3: [-0.33  0.82  0.47]
# 180 degrees rotation results in the tensor:
# [[25.022 -3.486 -0.789]
#  [-3.247 22.603  1.924]
#  [-1.114  1.97  23.289]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 8.29
#
# Skew is: -0.27
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[23.289  1.97  -1.114]
#  [ 1.924 22.603 -3.247]
#  [-0.789 -3.486 25.022]]
#
# Isotropic shielding: 23.64
#
# Mehring:
# [[19.86  0.    0.  ]
#  [ 0.   22.9   0.  ]
#  [ 0.    0.   28.15]]
#
# Unsorted Eigenvals:
# [28.15 22.9  19.86]
#
# Span is: 8.29
#
# Skew is: -0.27
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[25.841  0.596  0.668]
#  [ 0.8   21.952 -2.788]
#  [ 0.681 -2.191 23.483]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[25.841  0.8    0.681]
#  [ 0.596 21.952 -2.191]
#  [ 0.668 -2.788 23.483]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[25.841   0.698   0.6745]
#  [ 0.698  21.952  -2.4895]
#  [ 0.6745 -2.4895 23.483 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.102  -0.0065]
#  [ 0.102   0.     -0.2985]
#  [ 0.0065  0.2985  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [19.96 26.02 25.3 ], Eigenvectors are:
# [[-0.16  0.97 -0.17]
#  [ 0.79  0.02 -0.61]
#  [ 0.59  0.24  0.77]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [19.96 25.3  26.02]
#  and of eigenvectors is:
# [[-0.16 -0.17  0.97]
#  [ 0.79 -0.61  0.02]
#  [ 0.59  0.77  0.24]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[19.96  0.    0.  ]
#  [ 0.   26.02  0.  ]
#  [ 0.    0.   25.3 ]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 23.76 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[19.96  0.    0.  ]
#  [ 0.   25.3   0.  ]
#  [ 0.    0.   26.02]]
#
# where:
#  σ_11:19.96
#  σ_22:25.3
#  σ_33:26.02
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.16  0.79  0.59]
# Eigenvector row 2: [0.97 0.02 0.24]
# Eigenvector row 3: [-0.17 -0.61  0.77]
# 180 degrees rotation results in the tensor:
# [[23.483 -2.191  0.681]
#  [-2.788 21.952  0.8  ]
#  [ 0.668  0.596 25.841]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 6.06
#
# Skew is: 0.76
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[25.841  0.596  0.668]
#  [ 0.8   21.952 -2.788]
#  [ 0.681 -2.191 23.483]]
#
# Isotropic shielding: 23.76
#
# Mehring:
# [[19.96  0.    0.  ]
#  [ 0.   25.3   0.  ]
#  [ 0.    0.   26.02]]
#
# Unsorted Eigenvals:
# [19.96 26.02 25.3 ]
#
# Span is: 6.06
#
# Skew is: 0.76
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[22.981 -0.305  0.456]
#  [-0.11  22.392 -3.845]
#  [ 0.191 -3.932 25.443]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[22.981 -0.11   0.191]
#  [-0.305 22.392 -3.932]
#  [ 0.456 -3.845 25.443]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[22.981  -0.2075  0.3235]
#  [-0.2075 22.392  -3.8885]
#  [ 0.3235 -3.8885 25.443 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -0.0975  0.1325]
#  [ 0.0975  0.      0.0435]
#  [-0.1325 -0.0435  0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [28.12 22.95 19.74], Eigenvectors are:
# [[ 0.07 -1.   -0.  ]
#  [-0.56 -0.04  0.83]
# ...
# [[ 65.936  24.826 119.728]
#  [-17.029  -4.895 -40.478]
#  [ 13.592  -6.876   5.565]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[ 65.936 -17.029  13.592]
#  [ 24.826  -4.895  -6.876]
#  [119.728 -40.478   5.565]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[ 65.936    3.8985  66.66  ]
#  [  3.8985  -4.895  -23.677 ]
#  [ 66.66   -23.677    5.565 ]]
#
# Antisymmetric tensor is.
# [[  0.      20.9275  53.068 ]
#  [-20.9275   0.     -16.801 ]
#  [-53.068   16.801    0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [109.75 -48.65   5.51], Eigenvectors are:
# [[-0.83 -0.46 -0.32]
#  [ 0.09  0.45 -0.89]
#  [-0.55  0.76  0.34]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [  5.51 -48.65 109.75]
#  and of eigenvectors is:
# [[-0.32 -0.46 -0.83]
#  [-0.89  0.45  0.09]
#  [ 0.34  0.76 -0.55]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[109.75   0.     0.  ]
#  [  0.   -48.65   0.  ]
#  [  0.     0.     5.51]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 22.2 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[-48.65   0.     0.  ]
#  [  0.     5.51   0.  ]
#  [  0.     0.   109.75]]
#
# where:
#  σ_11:-48.65
#  σ_22:5.51
#  σ_33:109.75
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.83  0.09 -0.55]
# Eigenvector row 2: [-0.46  0.45  0.76]
# Eigenvector row 3: [-0.32 -0.89  0.34]
# 180 degrees rotation results in the tensor:
# [[  5.565  -6.876  13.592]
#  [-40.478  -4.895 -17.029]
#  [119.728  24.826  65.936]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 158.4
#
# Skew is: -0.32
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[ 65.936  24.826 119.728]
#  [-17.029  -4.895 -40.478]
#  [ 13.592  -6.876   5.565]]
#
# Isotropic shielding: 22.2
#
# Mehring:
# [[-48.65   0.     0.  ]
#  [  0.     5.51   0.  ]
#  [  0.     0.   109.75]]
#
# Unsorted Eigenvals:
# [109.75 -48.65   5.51]
#
# Span is: 158.4
#
# Skew is: -0.32
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[ 55.91   19.482  79.552]
#  [-13.349 -32.422 -89.858]
#  [  7.081  -4.53    9.015]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[ 55.91  -13.349   7.081]
#  [ 19.482 -32.422  -4.53 ]
#  [ 79.552 -89.858   9.015]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[ 55.91     3.0665  43.3165]
#  [  3.0665 -32.422  -47.194 ]
#  [ 43.3165 -47.194    9.015 ]]
#
# Antisymmetric tensor is.
# [[  0.      16.4155  36.2355]
#  [-16.4155   0.     -42.664 ]
#  [-36.2355  42.664    0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [ 86.28  15.5  -69.28], Eigenvectors are:
# [[-0.79 -0.57  0.22]
#  [ 0.21 -0.6  -0.78]
#  [-0.57  0.57 -0.59]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [ 15.5  -69.28  86.28]
#  and of eigenvectors is:
# [[-0.57  0.22 -0.79]
#  [-0.6  -0.78  0.21]
#  [ 0.57 -0.59 -0.57]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[ 86.28   0.     0.  ]
#  [  0.    15.5    0.  ]
#  [  0.     0.   -69.28]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 10.83 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[-69.28   0.     0.  ]
#  [  0.    15.5    0.  ]
#  [  0.     0.    86.28]]
#
# where:
#  σ_11:-69.28
#  σ_22:15.5
#  σ_33:86.28
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.79  0.21 -0.57]
# Eigenvector row 2: [-0.57 -0.6   0.57]
# Eigenvector row 3: [ 0.22 -0.78 -0.59]
# 180 degrees rotation results in the tensor:
# [[  9.015  -4.53    7.081]
#  [-89.858 -32.422 -13.349]
#  [ 79.552  19.482  55.91 ]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 155.56
#
# Skew is: 0.09
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[ 55.91   19.482  79.552]
#  [-13.349 -32.422 -89.858]
#  [  7.081  -4.53    9.015]]
#
# Isotropic shielding: 10.83
#
# Mehring:
# [[-69.28   0.     0.  ]
#  [  0.    15.5    0.  ]
#  [  0.     0.    86.28]]
#
# Unsorted Eigenvals:
# [ 86.28  15.5  -69.28]
#
# Span is: 155.56
#
# Skew is: 0.09
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[ 48.992  10.137  92.639]
#  [ -1.436 -57.205  40.97 ]
#  [ 14.986   7.346 -20.843]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[ 48.992  -1.436  14.986]
#  [ 10.137 -57.205   7.346]
#  [ 92.639  40.97  -20.843]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[ 48.992    4.3505  53.8125]
#  [  4.3505 -57.205   24.158 ]
#  [ 53.8125  24.158  -20.843 ]]
#
# Antisymmetric tensor is.
# [[  0.       5.7865  38.8265]
#  [ -5.7865   0.      16.812 ]
#  [-38.8265 -16.812    0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [ 79.98 -34.98 -74.05], Eigenvectors are:
# [[-0.86 -0.45 -0.23]
#  [-0.11  0.62 -0.78]
#  [-0.49  0.65  0.58]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [-34.98 -74.05  79.98]
#  and of eigenvectors is:
# [[-0.45 -0.23 -0.86]
#  [ 0.62 -0.78 -0.11]
#  [ 0.65  0.58 -0.49]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[ 79.98   0.     0.  ]
#  [  0.   -34.98   0.  ]
#  [  0.     0.   -74.05]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: -9.68 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[-74.05   0.     0.  ]
#  [  0.   -34.98   0.  ]
#  [  0.     0.    79.98]]
#
# where:
#  σ_11:-74.05
#  σ_22:-34.98
#  σ_33:79.98
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [-0.86 -0.11 -0.49]
# Eigenvector row 2: [-0.45  0.62  0.65]
# Eigenvector row 3: [-0.23 -0.78  0.58]
# 180 degrees rotation results in the tensor:
# [[-20.843   7.346  14.986]
#  [ 40.97  -57.205  -1.436]
#  [ 92.639  10.137  48.992]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 154.03
#
# Skew is: -0.49
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[ 48.992  10.137  92.639]
#  [ -1.436 -57.205  40.97 ]
#  [ 14.986   7.346 -20.843]]
#
# Isotropic shielding: -9.68
#
# Mehring:
# [[-74.05   0.     0.  ]
#  [  0.   -34.98   0.  ]
#  [  0.     0.    79.98]]
#
# Unsorted Eigenvals:
# [ 79.98 -34.98 -74.05]
#
# Span is: 154.03
#
# Skew is: -0.49
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[-35.522   3.28   64.527]
#  [  8.09  -40.247  21.845]
#  [ -2.509   0.319  -8.762]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[-35.522   8.09   -2.509]
#  [  3.28  -40.247   0.319]
#  [ 64.527  21.845  -8.762]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[-35.522   5.685  31.009]
#  [  5.685 -40.247  11.082]
#  [ 31.009  11.082  -8.762]]
#
# Antisymmetric tensor is.
# [[  0.     -2.405  33.518]
#  [  2.405   0.     10.763]
#  [-33.518 -10.763   0.   ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [ 14.44 -56.05 -42.92], Eigenvectors are:
# [[ 0.53  0.82  0.2 ]
#  [ 0.22  0.1  -0.97]
#  [ 0.82 -0.56  0.13]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [ 14.44 -42.92 -56.05]
#  and of eigenvectors is:
# [[ 0.53  0.2   0.82]
#  [ 0.22 -0.97  0.1 ]
#  [ 0.82  0.13 -0.56]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[ 14.44   0.     0.  ]
#  [  0.   -56.05   0.  ]
#  [  0.     0.   -42.92]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: -28.18 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[-56.05   0.     0.  ]
#  [  0.   -42.92   0.  ]
#  [  0.     0.    14.44]]
#
# where:
#  σ_11:-56.05
#  σ_22:-42.92
#  σ_33:14.44
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [0.53 0.22 0.82]
# Eigenvector row 2: [ 0.82  0.1  -0.56]
# Eigenvector row 3: [ 0.2  -0.97  0.13]
# 180 degrees rotation results in the tensor:
# [[ -8.762   0.319  -2.509]
#  [ 21.845 -40.247   8.09 ]
#  [ 64.527   3.28  -35.522]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 70.49
#
# Skew is: -0.63
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[-35.522   3.28   64.527]
#  [  8.09  -40.247  21.845]
#  [ -2.509   0.319  -8.762]]
#
# Isotropic shielding: -28.18
#
# Mehring:
# [[-56.05   0.     0.  ]
#  [  0.   -42.92   0.  ]
#  [  0.     0.    14.44]]
#
# Unsorted Eigenvals:
# [ 14.44 -56.05 -42.92]
#
# Span is: 70.49
#
# Skew is: -0.63
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[-111.978    5.516   46.442]
#  [  13.43   -11.672   27.919]
#  [ -10.609   -3.404  -29.184]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[-111.978   13.43   -10.609]
#  [   5.516  -11.672   -3.404]
#  [  46.442   27.919  -29.184]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[-111.978     9.473    17.9165]
#  [   9.473   -11.672    12.2575]
#  [  17.9165   12.2575  -29.184 ]]
#
# Antisymmetric tensor is.
# [[  0.      -3.957   28.5255]
#  [  3.957    0.      15.6615]
#  [-28.5255 -15.6615   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [-116.14   -2.74  -33.96], Eigenvectors are:
# [[-0.98  0.16  0.13]
#  [ 0.07  0.85 -0.52]
#  [ 0.19  0.5   0.84]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [  -2.74  -33.96 -116.14]
#  and of eigenvectors is:
# [[ 0.16  0.13 -0.98]
#  [ 0.85 -0.52  0.07]
#  [ 0.5   0.84  0.19]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[-116.14    0.      0.  ]
#  [   0.     -2.74    0.  ]
#  [   0.      0.    -33.96]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: -50.95 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[-116.14    0.      0.  ]
#  [   0.    -33.96    0.  ]
#  [   0.      0.     -2.74]]
#
# where:
#  σ_11:-116.14
#  σ_22:-33.96
#  σ_33:-2.74
#
# Proceeding to shielding tensor symmetry analysis...
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
#
# /var/folders/s_/t420f2pn6xq2bv06qkv7bdp40000gn/T/ipykernel_77693/3221549994.py:102: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nucprop_df = pd.concat([nucprop_df, datadf], ignore_index=True)
#                                 Molecule           Atom   x_coord   y_coord  \
# 0     KLaL_cation_pi_RCCE_opt_neg1p5.xyz   Nucleus 3H :   1.85056  -3.65399
# 1     KLaL_cation_pi_RCCE_opt_neg1p5.xyz   Nucleus 4H :  -1.00867  -3.16908
# 2     KLaL_cation_pi_RCCE_opt_neg1p5.xyz   Nucleus 7H :   2.41198  -2.20461
# 3     KLaL_cation_pi_RCCE_opt_neg1p5.xyz   Nucleus 9H :   3.34765   -1.9455
# 4     KLaL_cation_pi_RCCE_opt_neg1p5.xyz  Nucleus 11H :   2.39691  -3.29532
# ...                                  ...            ...       ...       ...
# 3467     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 51C :  -0.64706   4.78323
# 3468     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 57C :  -0.16135   2.99658
# 3469     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 52N :   -0.9608   5.43763
# 3470     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 54N :   -0.9621   6.44135
# 3471     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 59N :  -1.16151   4.94139
#
#         z_coord  sigma_iso  sigma_xx  sigma_yy  sigma_zz  dia_sigma_xx  ...  \
# 0     -14.42354      27.48     34.49     24.83     23.12        -84.19  ...
# 1     -13.28325      26.93     23.21     27.63     29.96        -63.17  ...
# 2     -16.88088      24.21     29.69     20.16     22.79        -51.87  ...
# 3     -17.38756      24.75     20.50     26.42     27.34         14.47  ...
# 4     -16.81784      24.16     29.66     20.16     22.66        136.21  ...
# ...         ...        ...       ...       ...       ...           ...  ...
# 3467  -14.92389      28.37    -58.28    104.06     39.33        155.14  ...
# 3468  -15.68304      26.93    124.43    -25.19    -18.44        228.50  ...
# 3469  -13.83124     175.86    115.64    183.03    228.92        400.42  ...
# 3470  -13.79599     176.95    229.48    181.91    119.47        197.29  ...
# 3471  -12.97253     176.70    229.15    182.11    118.83        392.58  ...
#
#       dia_sigma_zz  para_sigma_xx  para_sigma_yy  para_sigma_zz  sigma_11  \
# 0            15.18         110.38         -49.03          10.94     23.12
# 1            99.67          88.27          19.12         -72.09     23.21
# 2            94.15          76.55         -34.07         -71.21     20.16
# 3            63.21          11.32         -51.80         -40.55     20.50
# 4            59.12        -112.72          -0.88         -34.69     20.16
# ...            ...            ...            ...            ...       ...
# 3467        275.68         -83.31        -226.82        -335.90    -58.28
# 3468        299.89        -111.28        -281.37        -321.04    -25.19
# 3469        318.86        -240.69        -156.50        -129.94    115.64
# 3470        360.00         -15.57        -193.70        -129.68    119.47
# 3471        345.79        -204.12        -226.08         -97.68    118.83
#
#       sigma_22  sigma_33  s_tot_symmetry    span  skew
# 0        24.83     34.49               0   11.37 -0.70
# 1        27.63     29.96               0    6.75  0.31
# 2        22.79     29.69               0    9.53 -0.45
# 3        26.42     27.34               0    6.84  0.73
# 4        22.66     29.66               0    9.50 -0.47
# ...        ...       ...             ...     ...   ...
# 3467     39.33    104.06               0  162.34  0.20
# 3468    -18.44    124.43               0  149.62 -0.91
# 3469    183.03    228.92               0  113.28  0.19
# 3470    181.91    229.48               0  110.01  0.14
# 3471    182.11    229.15               0  110.32  0.15
#
# [3472 rows x 21 columns]

# %%
nucprop_df
# Out:
#                                 Molecule           Atom   x_coord   y_coord  \
# 0     KLaL_cation_pi_RCCE_opt_neg1p5.xyz   Nucleus 3H :   1.85056  -3.65399
# 1     KLaL_cation_pi_RCCE_opt_neg1p5.xyz   Nucleus 4H :  -1.00867  -3.16908
# 2     KLaL_cation_pi_RCCE_opt_neg1p5.xyz   Nucleus 7H :   2.41198  -2.20461
# 3     KLaL_cation_pi_RCCE_opt_neg1p5.xyz   Nucleus 9H :   3.34765   -1.9455
# 4     KLaL_cation_pi_RCCE_opt_neg1p5.xyz  Nucleus 11H :   2.39691  -3.29532
# ...                                  ...            ...       ...       ...
# 3467     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 51C :  -0.64706   4.78323
# 3468     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 57C :  -0.16135   2.99658
# 3469     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 52N :   -0.9608   5.43763
# 3470     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 54N :   -0.9621   6.44135
# 3471     KLaL_cation_pi_RCCE_opt_4p0.xyz  Nucleus 59N :  -1.16151   4.94139
#
#         z_coord  sigma_iso  sigma_xx  sigma_yy  sigma_zz  dia_sigma_xx  ...  \
# 0     -14.42354      27.48     34.49     24.83     23.12        -84.19  ...
# 1     -13.28325      26.93     23.21     27.63     29.96        -63.17  ...
# 2     -16.88088      24.21     29.69     20.16     22.79        -51.87  ...
# 3     -17.38756      24.75     20.50     26.42     27.34         14.47  ...
# 4     -16.81784      24.16     29.66     20.16     22.66        136.21  ...
# ...         ...        ...       ...       ...       ...           ...  ...
# 3467  -14.92389      28.37    -58.28    104.06     39.33        155.14  ...
# 3468  -15.68304      26.93    124.43    -25.19    -18.44        228.50  ...
# 3469  -13.83124     175.86    115.64    183.03    228.92        400.42  ...
# 3470  -13.79599     176.95    229.48    181.91    119.47        197.29  ...
# 3471  -12.97253     176.70    229.15    182.11    118.83        392.58  ...
#
#       dia_sigma_zz  para_sigma_xx  para_sigma_yy  para_sigma_zz  sigma_11  \
# 0            15.18         110.38         -49.03          10.94     23.12
# 1            99.67          88.27          19.12         -72.09     23.21
# 2            94.15          76.55         -34.07         -71.21     20.16
# 3            63.21          11.32         -51.80         -40.55     20.50
# 4            59.12        -112.72          -0.88         -34.69     20.16
# ...            ...            ...            ...            ...       ...
# 3467        275.68         -83.31        -226.82        -335.90    -58.28
# 3468        299.89        -111.28        -281.37        -321.04    -25.19
# 3469        318.86        -240.69        -156.50        -129.94    115.64
# 3470        360.00         -15.57        -193.70        -129.68    119.47
# 3471        345.79        -204.12        -226.08         -97.68    118.83
#
#       sigma_22  sigma_33  s_tot_symmetry    span  skew
# 0        24.83     34.49               0   11.37 -0.70
# 1        27.63     29.96               0    6.75  0.31
# 2        22.79     29.69               0    9.53 -0.45
# 3        26.42     27.34               0    6.84  0.73
# 4        22.66     29.66               0    9.50 -0.47
# ...        ...       ...             ...     ...   ...
# 3467     39.33    104.06               0  162.34  0.20
# 3468    -18.44    124.43               0  149.62 -0.91
# 3469    183.03    228.92               0  113.28  0.19
# 3470    181.91    229.48               0  110.01  0.14
# 3471    182.11    229.15               0  110.32  0.15
#
# [3472 rows x 21 columns]
