# %% [markdown]
# # CSA of 13C from the guanidinium of GLAL2 as monomer and dimer
# ## Details
# * monomer calculated at PBE0/pcSseg-2 LOT
# * dimer calculated at PBE0/pcSseg-1 LOT

# %%
# Get the NONCOVToolbox library and print header
# %load_ext autoreload
# %autoreload 2

import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import glob
import numpy as np
from sklearn.cluster import KMeans
import pathlib as Path
import importlib

path_noncov = os.path.abspath(os.path.join('..', '..', 'src'))

if path_noncov not in sys.path:
    sys.path.append(path_noncov)

from noncov import NONCOVToolbox, NONCOVHeader

noncov = NONCOVToolbox()

#NONCOVHeader.print_header()

# Show performance and features of various NMR functions in module
from noncov import NMRFunctions

# Disable printing
def blockPrint():
    sys.stdout = open(os.devnull, 'w')

# Restore printing
def enablePrint():
    sys.stdout = sys.__stdout__
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
MonomerCSA13C = [[120.274,          2.665,        42.176],
             [5.735,        -13.508,         2.337],
            [41.749,        1.091,       -18.002]]

DimerCSA13C = [[120.510, 4.861, 40.703], [6.972, -12.468, 1.481], [41.517, 0.547, -9.711]]

# %%
shielding_tensor, s_iso, diagonal_mehring, eigenvals, eigenvecs, symmetry, span, skew, diagonal_haberlen, red_anisotropy, asymmetry, anisotropy = NMRFunctions().diagonalize_tensor(DimerCSA13C)
# Out:
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[120.51    4.861  40.703]
#  [  6.972 -12.468   1.481]
#  [ 41.517   0.547  -9.711]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[120.51    6.972  41.517]
#  [  4.861 -12.468   0.547]
#  [ 40.703   1.481  -9.711]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[120.51     5.9165  41.11  ]
#  [  5.9165 -12.468    1.014 ]
#  [ 41.11     1.014   -9.711 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -1.0555 -0.407 ]
#  [ 1.0555  0.      0.467 ]
#  [ 0.407  -0.467   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [132.65 -21.65 -12.66], Eigenvectors are:
# [[ 0.96  0.28  0.02]
#  [ 0.04 -0.07 -1.  ]
#  [ 0.28 -0.96  0.08]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [-12.66 -21.65 132.65]
#  and of eigenvectors is:
# [[ 0.02  0.28  0.96]
#  [-1.   -0.07  0.04]
#  [ 0.08 -0.96  0.28]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[132.65   0.     0.  ]
#  [  0.   -21.65   0.  ]
#  [  0.     0.   -12.66]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 32.78 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[-21.65   0.     0.  ]
#  [  0.   -12.66   0.  ]
#  [  0.     0.   132.65]]
#
# where:
#  σ_11:-21.65
#  σ_22:-12.66
#  σ_33:132.65
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [0.96 0.04 0.28]
# Eigenvector row 2: [ 0.28 -0.07 -0.96]
# Eigenvector row 3: [ 0.02 -1.    0.08]
# 180 degrees rotation results in the tensor:
# [[ -9.711   0.547  41.517]
#  [  1.481 -12.468   6.972]
#  [ 40.703   4.861 120.51 ]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 154.3
#
# Skew is: -0.88
#
# Haberlen is: [99.87, -54.43, -45.44]
#
# Reduced anisotropy is: 99.87
#
# Asymmetry is: 0.09001702212876742
#
# Anisotropy is: 149.805
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[120.51    4.861  40.703]
#  [  6.972 -12.468   1.481]
#  [ 41.517   0.547  -9.711]]
#
# Isotropic shielding: 32.78
#
# Mehring:
# [[-21.65   0.     0.  ]
#  [  0.   -12.66   0.  ]
#  [  0.     0.   132.65]]
#
# Unsorted Eigenvals:
# [132.65 -21.65 -12.66]
#
# Span is: 154.3
#
# Skew is: -0.88
#
# Haberlen is: [99.87, -54.43, -45.44]
#
# Reduced anisotropy is: 99.87
#
# Asymmetry is: 0.09001702212876742
#
# Anisotropy is: 149.805
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #

# %%
shielding_tensor, s_iso, diagonal_mehring, eigenvals, eigenvecs, symmetry, span, skew, diagonal_haberlen, red_anisotropy, asymmetry, anisotropy = NMRFunctions().diagonalize_tensor(MonomerCSA13C)
# Out:
# # -------------------------------------------------- #
# # TENSOR DIAGONALIZATION FUNCTION HAS BEEN REQUESTED #
#
#
# Shielding Tensor is:
# [[120.274   2.665  42.176]
#  [  5.735 -13.508   2.337]
#  [ 41.749   1.091 -18.002]]
# Proceeding to transposing...
#
# Transposed matrix is:
# [[120.274   5.735  41.749]
#  [  2.665 -13.508   1.091]
#  [ 42.176   2.337 -18.002]]
# Proceeding to symmetrization...
#
# Symmetric tensor is:
# [[120.274    4.2     41.9625]
#  [  4.2    -13.508    1.714 ]
#  [ 41.9625   1.714  -18.002 ]]
#
# Antisymmetric tensor is.
# [[ 0.     -1.535   0.2135]
#  [ 1.535   0.      0.623 ]
#  [-0.2135 -0.623   0.    ]]
#
# Since antisymmetric part does not contribute to observable but only to relaxation, skipping...
#
# Proceeding to diagonalization...
#
# Eigenvalues are: [132.15 -29.76 -13.63], Eigenvectors are:
# [[ 0.96  0.27  0.04]
#  [ 0.03  0.03 -1.  ]
#  [ 0.27 -0.96 -0.02]]
#
# Proceeding to ordering eigenvalues and eigenvectors...
#
# Magnitude-based ordering of eigenvalues is:
# [-13.63 -29.76 132.15]
#  and of eigenvectors is:
# [[ 0.04  0.27  0.96]
#  [-1.    0.03  0.03]
#  [-0.02 -0.96  0.27]].
# Proceeding to diagonalization...
#
# Diagonalized tensor is:
# [[132.15   0.     0.  ]
#  [  0.   -29.76   0.  ]
#  [  0.     0.   -13.63]]
# Proceeding to compute isotropic shielding...
#
# Isotropic shielding is: 29.59 ppm
# Proceeding to Mehring ordering...
#
# Diagonal tensor in Mehring order is:
# [[-29.76   0.     0.  ]
#  [  0.   -13.63   0.  ]
#  [  0.     0.   132.15]]
#
# where:
#  σ_11:-29.76
#  σ_22:-13.63
#  σ_33:132.15
#
# Proceeding to shielding tensor symmetry analysis...
#
# Symmetry of the tensor based on eigenvals count is: 0
#
# which means that the tensor is completely anysotropic
#
# The tensor is not symmetric (S != S^T).
#
# Checking for rotational symmetry:
#
# Eigenvector row 1: [0.96 0.03 0.27]
# Eigenvector row 2: [ 0.27  0.03 -0.96]
# Eigenvector row 3: [ 0.04 -1.   -0.02]
# 180 degrees rotation results in the tensor:
# [[-18.002   1.091  41.749]
#  [  2.337 -13.508   5.735]
#  [ 42.176   2.665 120.274]]
#
# Rotational symmetry is:
# False
#
# Proceeding to compute span and skew of the tensor...
#
# Span is: 161.91
#
# Skew is: -0.8
#
# Haberlen is: [102.56, -59.35, -43.22]
#
# Reduced anisotropy is: 102.56
#
# Asymmetry is: 0.1572737909516381
#
# Anisotropy is: 153.84
#
# Summary of NMR parameters:
#
# Shielding tensor:
# [[120.274   2.665  42.176]
#  [  5.735 -13.508   2.337]
#  [ 41.749   1.091 -18.002]]
#
# Isotropic shielding: 29.59
#
# Mehring:
# [[-29.76   0.     0.  ]
#  [  0.   -13.63   0.  ]
#  [  0.     0.   132.15]]
#
# Unsorted Eigenvals:
# [132.15 -29.76 -13.63]
#
# Span is: 161.91
#
# Skew is: -0.8
#
# Haberlen is: [102.56, -59.35, -43.22]
#
# Reduced anisotropy is: 102.56
#
# Asymmetry is: 0.1572737909516381
#
# Anisotropy is: 153.84
#
# Proceeding...
#
# Call tensor_to_euler for Euler angles extraction from eigenvectors...
#
# # -------------------------------------------------- #

# %%
components = [abs(eigenvals[0]-s_iso), abs(eigenvals[1]-s_iso), abs(eigenvals[2]-s_iso)]

# %%
components
# Out:
# [102.56, 59.35, 43.22]

# %%
asymmetry = (components[2]-components[1]) / components[0]
asymmetry
# Out:
# -0.1572737909516381

# %%
anisotropy = (3*components[0])/2
anisotropy
# Out:
# 153.84
