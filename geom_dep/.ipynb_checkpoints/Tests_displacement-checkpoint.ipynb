# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Function to calculate the normal vector of a plane defined by 3 points
def calculate_normal(p1, p2, p3):
    v1 = np.array(p2) - np.array(p1)
    v2 = np.array(p3) - np.array(p1)
    
    # Cross product to find the normal vector
    normal = np.cross(v1, v2)
    
    # Normalize the normal vector
    norm = np.linalg.norm(normal)
    if norm == 0:
        raise ValueError("Points are collinear, cannot define a plane.")
    normal = normal / norm
    
    return normal

# Function to calculate the centroid (middle point) of the plane formed by 6 points
def calculate_centroid(points):
    centroid = np.mean(points, axis=0)
    return centroid

# Main function to find the plane and its normal vector at the centroid
def calculate_plane_and_normal(points, tolerance=1e-6):
    if len(points) != 6:
        raise ValueError("Exactly 6 points are required.")
    
    triangle1 = points[:3]
    triangle2 = points[3:]
    
    normal1 = calculate_normal(triangle1[0], triangle1[1], triangle1[2])
    normal2 = calculate_normal(triangle2[0], triangle2[1], triangle2[2])
    
    if not np.allclose(normal1, normal2, atol=tolerance):
        raise ValueError("The points do not lie on the same plane within the specified tolerance.")
    
    centroid = calculate_centroid(points)
    
    return normal1, normal2, centroid

# Plot the molecule, plane, and normal vectors
def plot_molecule_and_plane(points, normal1, normal2, centroid):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    points = np.array(points)
    
    # Plot the 6 points representing the atoms
    ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='r', s=100, label='Carbon Atoms')
    
    # Plot the plane (a rough approximation using centroid and normal)
    point  = centroid
    d = -point.dot(normal1)  # Plane equation: ax + by + cz + d = 0
    
    # Create a grid of points to plot the plane
    xx, yy = np.meshgrid(np.linspace(min(points[:, 0]), max(points[:, 0]), 10),
                         np.linspace(min(points[:, 1]), max(points[:, 1]), 10))
    zz = (-normal1[0] * xx - normal1[1] * yy - d) * 1. / normal1[2]
    
    ax.plot_surface(xx, yy, zz, color='b', alpha=0.3, rstride=100, cstride=100)

    # Plot the normal vectors for both triangles
    # For the first triangle
    triangle1_centroid = calculate_centroid(points[:3])
    ax.quiver(triangle1_centroid[0], triangle1_centroid[1], triangle1_centroid[2], 
              normal1[0], normal1[1], normal1[2], length=1.0, color='g', label='Normal 1')
    
    # For the second triangle
    triangle2_centroid = calculate_centroid(points[3:])
    ax.quiver(triangle2_centroid[0], triangle2_centroid[1], triangle2_centroid[2], 
              normal2[0], normal2[1], normal2[2], length=1.0, color='y', label='Normal 2')
    
    # Plot the centroid normal vector (combined normal for the whole plane)
    ax.quiver(centroid[0], centroid[1], centroid[2], 
              normal1[0], normal1[1], normal1[2], length=1.0, color='b', label='Normal (Full Plane)')
    
    # Set plot labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')
    
    # Add legend and show plot
    ax.legend()
    plt.show()

# Example usage
if __name__ == "__main__":
    # Input: 6 points in 3D space (x, y, z), all lying on the same plane (z = 0)
    points = [
        [1.0, 0.0, 0.0],  # Carbon atom positions on a hexagonal plane
        [0.5, 0.866, 0.0],
        [-0.5, 0.866, 0.0],
        [-1.0, 0.0, 0.0],
        [-0.5, -0.866, 0.0],
        [0.5, -0.866, 0.0]
    ]
    
    try:
        # Calculate the normal vectors and centroid of the plane
        normal1, normal2, centroid = calculate_plane_and_normal(points)
        
        # Output the normal vector direction
        print(f"Normal Vector 1 (Triangle 1): {normal1}")
        print(f"Normal Vector 2 (Triangle 2): {normal2}")
        print(f"Centroid of the Plane: {centroid}")
        
        # Output normal vector in coordinates
        print(f"Normal direction (x, y, z) for both triangles: {normal1[0]:.3f}, {normal1[1]:.3f}, {normal1[2]:.3f}")
        
        # Plot the molecule, plane, and normal vectors
        plot_molecule_and_plane(points, normal1, normal2, centroid)
        
    except ValueError as e:
        print(e)
# Out:
# Normal Vector 1 (Triangle 1): [0. 0. 1.]
# Normal Vector 2 (Triangle 2): [0. 0. 1.]
# Centroid of the Plane: [0. 0. 0.]
# Normal direction (x, y, z) for both triangles: 0.000, 0.000, 1.000

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Function to calculate the normal vector of a plane defined by 3 points
def calculate_normal(p1, p2, p3):
    v1 = np.array(p2) - np.array(p1)
    v2 = np.array(p3) - np.array(p1)
    
    # Cross product to find the normal vector
    normal = np.cross(v1, v2)
    
    # Normalize the normal vector
    norm = np.linalg.norm(normal)
    if norm == 0:
        raise ValueError("Points are collinear, cannot define a plane.")
    normal = normal / norm
    
    return normal

# Function to calculate the centroid (middle point) of the plane formed by 6 points
def calculate_centroid(points):
    centroid = np.mean(points, axis=0)
    return centroid

# Function to displace a point along a normal direction
def displace_point_along_normal(point, normal, step, k):
    displaced_points = []
    for i in range(k):
        displaced_point = point + normal * step * (i + 1)
        displaced_points.append(displaced_point)
    return np.array(displaced_points)

# Main function to find the plane and its normal vector at the centroid
def calculate_plane_and_normal(points, tolerance=1e-6):
    if len(points) != 6:
        raise ValueError("Exactly 6 points are required.")
    
    triangle1 = points[:3]
    triangle2 = points[3:]
    
    normal1 = calculate_normal(triangle1[0], triangle1[1], triangle1[2])
    normal2 = calculate_normal(triangle2[0], triangle2[1], triangle2[2])
    
    if not np.allclose(normal1, normal2, atol=tolerance):
        raise ValueError("The points do not lie on the same plane within the specified tolerance.")
    
    centroid = calculate_centroid(points)
    
    return normal1, normal2, centroid

# Plot the molecule, plane, and normal vectors
def plot_molecule_and_plane(points, normal1, normal2, centroid, point_above_plane, displaced_points):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    points = np.array(points)
    
    # Plot the 6 points representing the atoms
    ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='r', s=100, label='Carbon Atoms')
    
    # Plot the plane (a rough approximation using centroid and normal)
    point  = centroid
    d = -point.dot(normal1)  # Plane equation: ax + by + cz + d = 0
    
    # Create a grid of points to plot the plane
    xx, yy = np.meshgrid(np.linspace(min(points[:, 0]), max(points[:, 0]), 10),
                         np.linspace(min(points[:, 1]), max(points[:, 1]), 10))
    zz = (-normal1[0] * xx - normal1[1] * yy - d) * 1. / normal1[2]
    
    ax.plot_surface(xx, yy, zz, color='b', alpha=0.3, rstride=100, cstride=100)

    # Plot the normal vectors for both triangles
    # For the first triangle
    triangle1_centroid = calculate_centroid(points[:3])
    ax.quiver(triangle1_centroid[0], triangle1_centroid[1], triangle1_centroid[2], 
              normal1[0], normal1[1], normal1[2], length=1.0, color='g')
    
    # For the second triangle
    triangle2_centroid = calculate_centroid(points[3:])
    ax.quiver(triangle2_centroid[0], triangle2_centroid[1], triangle2_centroid[2], 
              normal2[0], normal2[1], normal2[2], length=1.0, color='y')
    
    # Plot the centroid normal vector (combined normal for the whole plane)
    ax.quiver(centroid[0], centroid[1], centroid[2], 
              normal1[0], normal1[1], normal1[2], length=1.0, color='b', label='Normal')
    
    # Plot the point above the plane
    ax.scatter(point_above_plane[0], point_above_plane[1], point_above_plane[2], color='k', s=100, label='Nuc x')

    # Plot the displaced points along the normal direction
    displaced_points = np.array(displaced_points)
    ax.scatter(displaced_points[:, 0], displaced_points[:, 1], displaced_points[:, 2], color='orange', s=50, label='Disp')
    
    # Plot the trajectory of the displaced points
    ax.plot(displaced_points[:, 0], displaced_points[:, 1], displaced_points[:, 2], color='orange', label='Trajectory')
    
    # Set plot labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')
    
    # Add legend and show plot
    ax.legend()
    plt.show()

# Example usage
if __name__ == "__main__":
    # Input: 6 points in 3D space (x, y, z), all lying on the same plane (z = 0)
    points = [
        [1.0, 0.0, 0.0],  # Carbon atom positions on a hexagonal plane
        [0.5, 0.866, 0.0],
        [-0.5, 0.866, 0.0],
        [-1.0, 0.0, 0.0],
        [-0.5, -0.866, 0.0],
        [0.5, -0.866, 0.0]
    ]
    
    # Point above the plane
    point_above_plane = np.array([0.3, 0.2, 1.0])  # This is the point initially at (0,0,1)
    
    try:
        # Calculate the normal vectors and centroid of the plane
        normal1, normal2, centroid = calculate_plane_and_normal(points)
        
        # Output the normal vector direction
        print(f"Normal Vector 1 (Triangle 1): {normal1}")
        print(f"Normal Vector 2 (Triangle 2): {normal2}")
        print(f"Centroid of the Plane: {centroid}")
        
        # Output normal vector in coordinates
        print(f"Normal direction (x, y, z) for both triangles: {normal1[0]:.3f}, {normal1[1]:.3f}, {normal1[2]:.3f}")
        
        # Displace the point above the plane along the normal direction
        step = 0.2  # Displacement step size
        k = 10      # Number of times to displace the point
        displaced_points = displace_point_along_normal(point_above_plane, normal1, step, k)
        
        # Plot the molecule, plane, normal vectors, and displaced points
        plot_molecule_and_plane(points, normal1, normal2, centroid, point_above_plane, displaced_points)
        
    except ValueError as e:
        print(e)
# Out:
# Normal Vector 1 (Triangle 1): [0. 0. 1.]
# Normal Vector 2 (Triangle 2): [0. 0. 1.]
# Centroid of the Plane: [0. 0. 0.]
# Normal direction (x, y, z) for both triangles: 0.000, 0.000, 1.000

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Function to calculate the normal vector of a plane defined by 3 points
def calculate_normal(p1, p2, p3):
    v1 = np.array(p2) - np.array(p1)
    v2 = np.array(p3) - np.array(p1)
    
    # Cross product to find the normal vector
    normal = np.cross(v1, v2)
    
    # Normalize the normal vector
    norm = np.linalg.norm(normal)
    if norm == 0:
        raise ValueError("Points are collinear, cannot define a plane.")
    normal = normal / norm
    
    return normal

# Function to calculate the centroid (middle point) of the plane formed by 6 points
def calculate_centroid(points):
    centroid = np.mean(points, axis=0)
    return centroid

# Function to displace a point along a normal direction
def displace_point_along_normal(point, normal, step, k):
    displaced_points = []
    for i in range(k):
        displaced_point = point + normal * step * (i + 1)
        displaced_points.append(displaced_point)
    return np.array(displaced_points)

# Function to calculate the angle theta between the normal and the vector to the point
def calculate_angle_between_vectors(normal, vector_to_point):
    dot_product = np.dot(normal, vector_to_point)
    norm_normal = np.linalg.norm(normal)
    norm_vector_to_point = np.linalg.norm(vector_to_point)
    
    # Calculate cosine of theta
    cos_theta = dot_product / (norm_normal * norm_vector_to_point)
    
    # Calculate angle in radians, then convert to degrees
    theta = np.arccos(cos_theta)  # in radians
    theta_degrees = np.degrees(theta)  # in degrees
    
    return theta_degrees

# Main function to find the plane and its normal vector at the centroid
def calculate_plane_and_normal(points, tolerance=1e-1):
    if len(points) != 6:
        raise ValueError("Exactly 6 points are required.")
    
    triangle1 = points[:3]
    triangle2 = points[3:]
    
    normal1 = calculate_normal(triangle1[0], triangle1[1], triangle1[2])
    normal2 = calculate_normal(triangle2[0], triangle2[1], triangle2[2])
    
    if not np.allclose(normal1, normal2, atol=tolerance):
        raise ValueError("The points do not lie on the same plane within the specified tolerance.")
    
    centroid = calculate_centroid(points)
    
    return normal1, normal2, centroid

# Plot the molecule, plane, and normal vectors
def plot_molecule_and_plane(points, normal1, normal2, centroid, point_above_plane, displaced_points):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    points = np.array(points)
    
    # Plot the 6 points representing the atoms
    ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='r', s=100, label='Carbon Atoms')
    
    # Plot the plane (a rough approximation using centroid and normal)
    point  = centroid
    d = -point.dot(normal1)  # Plane equation: ax + by + cz + d = 0
    
    # Create a grid of points to plot the plane
    xx, yy = np.meshgrid(np.linspace(min(points[:, 0]), max(points[:, 0]), 10),
                         np.linspace(min(points[:, 1]), max(points[:, 1]), 10))
    zz = (-normal1[0] * xx - normal1[1] * yy - d) * 1. / normal1[2]
    
    ax.plot_surface(xx, yy, zz, color='b', alpha=0.3, rstride=100, cstride=100)

    # Plot the normal vectors for both triangles
    # For the first triangle
    triangle1_centroid = calculate_centroid(points[:3])
    ax.quiver(triangle1_centroid[0], triangle1_centroid[1], triangle1_centroid[2], 
              normal1[0], normal1[1], normal1[2], length=1.0, color='g', label='Normal 1')
    
    # For the second triangle
    triangle2_centroid = calculate_centroid(points[3:])
    ax.quiver(triangle2_centroid[0], triangle2_centroid[1], triangle2_centroid[2], 
              normal2[0], normal2[1], normal2[2], length=1.0, color='y', label='Normal 2')
    
    # Plot the centroid normal vector (combined normal for the whole plane)
    ax.quiver(centroid[0], centroid[1], centroid[2], 
              normal1[0], normal1[1], normal1[2], length=1.0, color='b', label='Normal (Full Plane)')
    
    # Plot the point above the plane
    ax.scatter(point_above_plane[0], point_above_plane[1], point_above_plane[2], color='k', s=100, label='Point above Plane')

    # Plot the displaced points along the normal direction
    displaced_points = np.array(displaced_points)
    ax.scatter(displaced_points[:, 0], displaced_points[:, 1], displaced_points[:, 2], color='orange', s=50, label='Displaced Points')
    
    # Plot the trajectory of the displaced points
    ax.plot(displaced_points[:, 0], displaced_points[:, 1], displaced_points[:, 2], color='orange', label='Trajectory')
    
    # Plot centroid of aromatic
    ax.scatter(centroid[0], centroid[1], centroid[2], color='g', s=50, label='Aromatic centroid')
    
    # Set plot labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')
    
    # Add legend and show plot
    ax.legend()
    plt.show()

# Example usage
if __name__ == "__main__":
    # Input: 6 points in 3D space (x, y, z), all lying on the same plane (z = 0)
    points = [
        [-0.51724, 0.54821, 0.35582],  # Carbon atom positions on a hexagonal plane
        [-1.15680, 1.08010, -0.76605],
        [-2.54090, 1.20110, -0.78853],
        [-3.29528, 0.79560, 0.30810],
        [-2.66210, 0.26887, 1.42834],
        [-1.27710, 0.14437, 1.45429]
        ]
    
    # Point above the plane
    point_above_plane = np.array([0.0, 0.0, 0.0])  # This is the point initially at (0,0,1)
    
    try:
        # Calculate the normal vectors and centroid of the plane
        normal1, normal2, centroid = calculate_plane_and_normal(points)
        
        # Output the normal vector direction
        print(f"Normal Vector 1 (Triangle 1): {normal1}")
        print(f"Normal Vector 2 (Triangle 2): {normal2}")
        print(f"Centroid of the Plane: {centroid}")
        
        # Output normal vector in coordinates
        print(f"Normal direction (x, y, z) for both triangles: {normal1[0]:.3f}, {normal1[1]:.3f}, {normal1[2]:.3f}")
        
        # Compute the vector from the centroid to the point above the plane
        vector_to_point = point_above_plane - centroid
        
        # Calculate the angle between the normal and the vector to the point
        theta = calculate_angle_between_vectors(normal1, vector_to_point)
        print(f"Angle θ between normal and vector to point: {theta:.2f} degrees")
        
        # Displace the point above the plane along the normal direction
        step = 0.2  # Displacement step size
        k = 10      # Number of times to displace the point
        displaced_points = displace_point_along_normal(point_above_plane, normal1, step, k)
        
        # Plot the molecule, plane, normal vectors, and displaced points
        plot_molecule_and_plane(points, normal1, normal2, centroid, point_above_plane, displaced_points)
        
    except ValueError as e:
        print(e)
# Out:
# Normal Vector 1 (Triangle 1): [0.07376748 0.91675152 0.39258759]
# Normal Vector 2 (Triangle 2): [0.07523761 0.91809396 0.3891565 ]
# Centroid of the Plane: [-1.90823667  0.67304167  0.331995  ]
# Normal direction (x, y, z) for both triangles: 0.074, 0.917, 0.393
# Angle θ between normal and vector to point: 107.21 degrees

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d.art3d import Poly3DCollection

# Function to calculate the normal vector using PCA on any number of points (>=3)
def calculate_plane_and_normal(points, tolerance=1e-1):
    if len(points) < 3:
        raise ValueError("At least 3 points are required to define a plane.")
    
    # Calculate the centroid
    centroid = calculate_centroid(points)
    
    # Subtract the centroid from the points (centering the points)
    centered_points = points - centroid
    
    # Compute the covariance matrix of the centered points
    covariance_matrix = np.cov(centered_points.T)
    
    # Perform eigen-decomposition to find the eigenvectors and eigenvalues
    eigenvalues, eigenvectors = np.linalg.eig(covariance_matrix)
    
    # The normal vector to the plane is the eigenvector corresponding to the smallest eigenvalue
    normal = eigenvectors[:, np.argmin(eigenvalues)]
    
    # Normalize the normal vector
    normal /= np.linalg.norm(normal)
    
    return normal, centroid

# Function to calculate the centroid (middle point) of the plane formed by points
def calculate_centroid(points):
    centroid = np.mean(points, axis=0)
    return centroid

# Function to displace a point along a normal direction
def displace_point_along_normal(point, normal, step, k):
    displaced_points = []
    for i in range(k):
        displaced_point = point + normal * step * (i + 1)
        displaced_points.append(displaced_point)
    return np.array(displaced_points)

# Function to calculate the angle theta between the normal and the vector to the point
def calculate_angle_between_vectors(normal, vector_to_point):
    dot_product = np.dot(normal, vector_to_point)
    norm_normal = np.linalg.norm(normal)
    norm_vector_to_point = np.linalg.norm(vector_to_point)
    
    # Calculate cosine of theta
    cos_theta = dot_product / (norm_normal * norm_vector_to_point)
    
    # Calculate angle in radians, then convert to degrees
    theta = np.arccos(cos_theta)  # in radians
    theta_degrees = np.degrees(theta)  # in degrees
    
    return theta_degrees

# Plot the molecule, plane, and normal vectors
def plot_molecule_and_plane(points, normal, centroid, point_above_plane, displaced_points):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    points = np.array(points)
    
    # Plot the points representing the atoms
    ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='r', s=100, label='Atoms')
    
    # Plot the plane (a rough approximation using centroid and normal)
    point  = centroid
    d = -point.dot(normal)  # Plane equation: ax + by + cz + d = 0
    
    # Create a grid of points to plot the plane
    xx, yy = np.meshgrid(np.linspace(min(points[:, 0]), max(points[:, 0]), 10),
                         np.linspace(min(points[:, 1]), max(points[:, 1]), 10))
    zz = (-normal[0] * xx - normal[1] * yy - d) * 1. / normal[2]
    
    ax.plot_surface(xx, yy, zz, color='b', alpha=0.3, rstride=100, cstride=100)

    # Plot the normal vector for the plane
    ax.quiver(centroid[0], centroid[1], centroid[2], 
              normal[0], normal[1], normal[2], length=1.0, color='b', label='Normal (Full Plane)')
    
    # Plot the point above the plane
    ax.scatter(point_above_plane[0], point_above_plane[1], point_above_plane[2], color='k', s=100, label='Point above Plane')

    # Plot the displaced points along the normal direction
    displaced_points = np.array(displaced_points)
    ax.scatter(displaced_points[:, 0], displaced_points[:, 1], displaced_points[:, 2], color='orange', s=50, label='Displaced Points')
    
    # Plot the trajectory of the displaced points
    ax.plot(displaced_points[:, 0], displaced_points[:, 1], displaced_points[:, 2], color='orange', label='Trajectory')
    
    # Plot centroid of the points
    ax.scatter(centroid[0], centroid[1], centroid[2], color='g', s=50, label='Centroid')
    
    # Set plot labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')
    
    # Add legend and show plot
    ax.legend()
    plt.show()

# Example usage
if __name__ == "__main__":
    # Input: 5 or 6 points in 3D space (x, y, z), all lying on the same plane (z = 0)
    points_6 = np.array([
        [-0.51724, 0.54821, 0.35582],  # Carbon atom positions on a hexagonal plane
        [-1.15680, 1.08010, -0.76605],
        [-2.54090, 1.20110, -0.78853],
        [-3.29528, 0.79560, 0.30810],
        [-2.66210, 0.26887, 1.42834],
        [-1.27710, 0.14437, 1.45429]
    ])

    points_5 = np.array([
        [-0.51724, 0.54821, 0.35582],  # Carbon atom positions on a pentagonal plane
        [-1.15680, 1.08010, -0.76605],
        [-2.54090, 1.20110, -0.78853],
        [-2.66210, 0.26887, 1.42834],
        [-1.27710, 0.14437, 1.45429]
    ])
    
    # Point above the plane
    point_above_plane = np.array([0.0, 0.0, 0.0])
    
    try:
        # Select points: use either points_6 or points_5
        points = points_5  # Choose points_6 for 6-point example
        
        # Calculate the normal vectors and centroid of the plane
        normal, centroid = calculate_plane_and_normal(points)
        
        # Output the normal vector direction
        print(f"Normal Vector: {normal}")
        print(f"Centroid of the Plane: {centroid}")
        
        # Compute the vector from the centroid to the point above the plane
        vector_to_point = point_above_plane - centroid
        
        # Calculate the angle between the normal and the vector to the point
        theta = calculate_angle_between_vectors(normal, vector_to_point)
        print(f"Angle θ between normal and vector to point: {theta:.2f} degrees")
        
        # Displace the point above the plane along the normal direction
        step = 0.2  # Displacement step size
        k = 10      # Number of times to displace the point
        displaced_points = displace_point_along_normal(point_above_plane, normal, step, k)
        
        # Plot the molecule, plane, normal vectors, and displaced points
        plot_molecule_and_plane(points, normal, centroid, point_above_plane, displaced_points)
        
    except ValueError as e:
        print(e)
# Out:
# Normal Vector: [-0.07517703 -0.91758256 -0.39037247]
# Centroid of the Plane: [-1.630828  0.64853   0.336774]
# Angle θ between normal and vector to point: 70.25 degrees

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function to calculate the normal vector using cross product from three points
def calculate_plane_from_three_points(q, r, s):
    # Vectors QR and QS
    qr = r - q
    qs = s - q
    
    # Normal vector to the plane (QR x QS)
    normal = np.cross(qr, qs)
    
    # Normalize the normal vector
    normal /= np.linalg.norm(normal)
    
    return normal

# Function to calculate the centroid (average point) of the points
def calculate_centroid(points):
    return np.mean(points, axis=0)

# Function to calculate the plane equation Ax + By + Cz + D = 0
def calculate_plane_equation(normal, point):
    A, B, C = normal
    x0, y0, z0 = point
    
    # D is calculated as -(Ax0 + By0 + Cz0)
    D = -(A * x0 + B * y0 + C * z0)
    
    return A, B, C, D

# Function to plot the plane and normal vector
def plot_molecule_and_plane(points, normal, centroid, displaced_points):
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    
    points = np.array(points)
    
    # Plot the points representing the atoms
    ax.scatter(points[:, 0], points[:, 1], points[:, 2], color='r', s=100, label='Atoms')
    
    # Plot the plane passing through the centroid
    d = -centroid.dot(normal)  # Plane equation: ax + by + cz + d = 0
    
    # Create a grid of points to plot the plane
    xx, yy = np.meshgrid(np.linspace(min(points[:, 0]), max(points[:, 0]), 10),
                         np.linspace(min(points[:, 1]), max(points[:, 1]), 10))
    zz = (-normal[0] * xx - normal[1] * yy - d) / normal[2]
    
    ax.plot_surface(xx, yy, zz, color='b', alpha=0.3, rstride=100, cstride=100)
    
    # Plot the normal vector at the centroid
    ax.quiver(centroid[0], centroid[1], centroid[2], 
              normal[0], normal[1], normal[2], length=1.0, color='b', label='Normal (Plane)')
    
    # Plot the displaced points along the normal direction
    displaced_points = np.array(displaced_points)
    ax.scatter(displaced_points[:, 0], displaced_points[:, 1], displaced_points[:, 2], color='orange', s=50, label='Displaced Points')
    
    # Plot the trajectory of the displaced points
    ax.plot(displaced_points[:, 0], displaced_points[:, 1], displaced_points[:, 2], color='orange', label='Trajectory')
    
    # Plot centroid
    ax.scatter(centroid[0], centroid[1], centroid[2], color='g', s=50, label='Centroid')
    
    # Set plot labels
    ax.set_xlabel('X-axis')
    ax.set_ylabel('Y-axis')
    ax.set_zlabel('Z-axis')
    
    # Add legend and show plot
    ax.legend()
    plt.show()

# Example usage
if __name__ == "__main__":
    # Input: 6 points in 3D space (x, y, z)
    points = np.array([
        [-0.51724, 0.54821, 0.35582],
        [-1.15680, 1.08010, -0.76605],
        [-2.54090, 1.20110, -0.78853],
        [-3.29528, 0.79560, 0.30810],
        [-2.66210, 0.26887, 1.42834],
        [-1.27710, 0.14437, 1.45429]
    ])
    
    # Calculate the normal vector using the first three points
    q, r, s = points[0], points[2], points[5]
    normal = calculate_plane_from_three_points(q, r, s)
    
    # Calculate the centroid of the points
    centroid = calculate_centroid(points)
    
    # Calculate the plane equation Ax + By + Cz + D = 0
    A, B, C, D = calculate_plane_equation(normal, q)
    print(f"Plane equation: {A:.2f}x + {B:.2f}y + {C:.2f}z + {D:.2f} = 0")
    
    # Displace the point along the normal
    step = 0.2  # Displacement step size
    k = 10      # Number of steps
    displaced_points = [centroid + normal * step * i for i in range(k)]
    
    # Plot the molecule, plane, normal vectors, and displaced points
    plot_molecule_and_plane(points, normal, centroid, displaced_points)
# Out:
# Plane equation: 0.08x + 0.92y + 0.39z + -0.60 = 0
