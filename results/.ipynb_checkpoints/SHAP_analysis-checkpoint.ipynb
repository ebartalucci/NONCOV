# %%
# Get the NONCOVToolbox library and print header
import sys
import os
import pandas as pd
import matplotlib.pyplot as plt
import glob
import numpy as np
from sklearn.cluster import KMeans
import pathlib as Path
import seaborn as sns

# %%
# Display how the empty databases look like
nucprop_df = pd.read_csv("C:/Users/ettor/Desktop/NONCOV/scratch/GenerateMLDataset/data/nuc_prop_nmr_observables.csv")
nucprop_df.head()
# Out:
#                                Molecule          Atom   x_coord   y_coord  \
# 0  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 0H :  1.262496 -0.430661
# 1  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 3H :  0.725262 -0.290962
# 2  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 5H : -0.653711 -0.107857
# 3  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 7H : -1.192142 -0.111533
# 4  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 9H : -1.341293  0.087002
#
#     z_coord  sigma_iso  sigma_xx  sigma_yy  sigma_zz  dia_sigma_xx  \
# 0  2.134433      23.67     27.05     23.10     20.85         43.22
# 1  1.201459      23.79     27.01     23.39     20.98         43.09
# 2  1.215100      23.88     21.06     23.61     26.97         42.63
# 3  2.158714      23.62     27.01     22.98     20.88         43.39
# 4  0.021568      23.64     27.06     23.03     20.83         42.79
#
#    dia_sigma_yy  dia_sigma_zz  para_sigma_xx  para_sigma_yy  para_sigma_zz  \
# 0         28.25         21.04         -20.23          -1.20          -0.08
# 1         29.18         22.81         -19.89          -2.33          -1.49
# 2         23.59         29.92         -19.27          -2.39          -2.85
# 3         28.25         21.75         -20.56          -1.31          -0.64
# 4         28.70         21.04         -19.88          -1.64          -0.10
#
#    sigma_11  sigma_22  sigma_33  s_tot_symmetry
# 0     20.85     23.10     27.05               0
# 1     20.98     23.39     27.01               0
# 2     21.06     23.61     26.97               0
# 3     20.88     22.98     27.01               0
# 4     20.83     23.03     27.06               0

# %%
nucprop_df = nucprop_df.applymap(lambda x: np.real(x))
nucprop_df.head()
# Out:
#                                Molecule          Atom   x_coord   y_coord  \
# 0  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 0H :  1.262496 -0.430661
# 1  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 3H :  0.725262 -0.290962
# 2  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 5H : -0.653711 -0.107857
# 3  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 7H : -1.192142 -0.111533
# 4  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 9H : -1.341293  0.087002
#
#     z_coord  sigma_iso  sigma_xx  sigma_yy  sigma_zz  dia_sigma_xx  \
# 0  2.134433      23.67     27.05     23.10     20.85         43.22
# 1  1.201459      23.79     27.01     23.39     20.98         43.09
# 2  1.215100      23.88     21.06     23.61     26.97         42.63
# 3  2.158714      23.62     27.01     22.98     20.88         43.39
# 4  0.021568      23.64     27.06     23.03     20.83         42.79
#
#    dia_sigma_yy  dia_sigma_zz  para_sigma_xx  para_sigma_yy  para_sigma_zz  \
# 0         28.25         21.04         -20.23          -1.20          -0.08
# 1         29.18         22.81         -19.89          -2.33          -1.49
# 2         23.59         29.92         -19.27          -2.39          -2.85
# 3         28.25         21.75         -20.56          -1.31          -0.64
# 4         28.70         21.04         -19.88          -1.64          -0.10
#
#    sigma_11  sigma_22  sigma_33  s_tot_symmetry
# 0     20.85     23.10     27.05               0
# 1     20.98     23.39     27.01               0
# 2     21.06     23.61     26.97               0
# 3     20.88     22.98     27.01               0
# 4     20.83     23.03     27.06               0

# %%
nucprop_df['sigma_iso'] = nucprop_df['sigma_iso'].str.replace(r'\D','').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-acb014599bda> in <module>
# ----> 1 nucprop_df['sigma_iso'] = nucprop_df['sigma_iso'].str.replace(r'\D','').astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5133             or name in self._accessors
#    5134         ):
# -> 5135             return object.__getattribute__(self, name)
#    5136         else:
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     185             # we're accessing the attribute of the class, i.e., Dataset.geo
#     186             return self._accessor
# --> 187         accessor_obj = self._accessor(obj)
#     188         # Replace the property with the accessor object. Inspired by:
#     189         # https://www.pydanny.com/cached-property.html
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in __init__(self, data)
#    2098
#    2099     def __init__(self, data):
# -> 2100         self._inferred_dtype = self._validate(data)
#    2101         self._is_categorical = is_categorical_dtype(data.dtype)
#    2102         self._is_string = data.dtype.name == "string"
#
# ~\anaconda3\lib\site-packages\pandas\core\strings.py in _validate(data)
#    2155
#    2156         if inferred_dtype not in allowed_types:
# -> 2157             raise AttributeError("Can only use .str accessor with string values!")
#    2158         return inferred_dtype
#    2159
#
# AttributeError: Can only use .str accessor with string values!

# %%
nucprop_df.head()
# Out:
#                                Molecule          Atom   x_coord   y_coord  \
# 0  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 0H :  1.262496 -0.430661
# 1  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 3H :  0.725262 -0.290962
# 2  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 5H : -0.653711 -0.107857
# 3  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 7H : -1.192142 -0.111533
# 4  benzene_H2O_relaxH_disp_struct_0.xyz  Nucleus 9H : -1.341293  0.087002
#
#     z_coord  sigma_iso  sigma_xx  sigma_yy  sigma_zz  dia_sigma_xx  \
# 0  2.134433      23.67     27.05     23.10     20.85         43.22
# 1  1.201459      23.79     27.01     23.39     20.98         43.09
# 2  1.215100      23.88     21.06     23.61     26.97         42.63
# 3  2.158714      23.62     27.01     22.98     20.88         43.39
# 4  0.021568      23.64     27.06     23.03     20.83         42.79
#
#    dia_sigma_yy  dia_sigma_zz  para_sigma_xx  para_sigma_yy  para_sigma_zz  \
# 0         28.25         21.04         -20.23          -1.20          -0.08
# 1         29.18         22.81         -19.89          -2.33          -1.49
# 2         23.59         29.92         -19.27          -2.39          -2.85
# 3         28.25         21.75         -20.56          -1.31          -0.64
# 4         28.70         21.04         -19.88          -1.64          -0.10
#
#    sigma_11  sigma_22  sigma_33  s_tot_symmetry
# 0     20.85     23.10     27.05               0
# 1     20.98     23.39     27.01               0
# 2     21.06     23.61     26.97               0
# 3     20.88     22.98     27.01               0
# 4     20.83     23.03     27.06               0

# %%
sns.displot(np.real(nucprop_df.sigma_iso))
plt.show()
